# %% [markdown]
# ### Import the QAutoencoder class & MNIST data class and call it

# %%
# file class_QAutoencoder.py
from class_QAutoencoder import *
# from class_QAutoencoder_mini import *
import MNIST_database as mnist

# %% [markdown]
# Original dataset and modified dataset with modifiable resolution is shown below.

# %%
# import MNIST_dataset as mnist
# size_final = 28

# data = mnist.MNISTData(size_initial=28, size_final=size_final, color_depth=8)
# train= data.x_train
# ax = plt.subplot(1, 1 , 1)

# plt.imshow(train[0].reshape(size_final,size_final), cmap='gray_r')
# ax.get_xaxis().set_visible(False)
# ax.get_yaxis().set_visible(False)

# %%
#Choose the final size of your image dataset
size_final = 8

# data_zoom = mnist.MNISTData(size_initial=20, size_final=size_final, color_depth=5, flat=True)
data_zoom = mnist.MNISTData(size_initial=20, size_final=8, color_depth=8, flat=True)

train= data_zoom.x_train
ax = plt.subplot(1, 1 , 1)

plt.imshow(train[0].reshape(size_final,size_final), cmap='gray_r')
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)

# %% [markdown]
# # Autoencoder using Keras
# The aim of this class is to implement a simple autoencoder for the MNIST data and then build an autoencoder that is
# able to classify MNIST data in its latent dimension.
#
# Code partially adapted from [Keras Documentation](https://blog.keras.io/building-autoencoders-in-keras.html).

# %%
BIT_WIDTH = 8

# %% [markdown]
# # QAutoencoder without classifier

# %% [markdown]
# It is built the standard autoencoder, *without classifier* here, and the MNIST data class called before is used.
# The model is fitted and adequate plots are reproduced,
# as well as the comparison between orginal MNIST dataset and reconstructed images.

# %%
network = QAutoencoder(data_zoom, pruned=False, BIT_WIDTH = BIT_WIDTH)
network.build_encoder()
network.build_decoder()
network.build_autoencoder()
network.fit_data(epochs=40)
# Out:
# Model: "autoencoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  encoder_input (InputLayer)  [(None, 64)]              0
#
#  fc1 (QDense)                (None, 15)                975
#
#  relu1 (QActivation)         (None, 15)                0
#
#  fc2 (QDense)                (None, 15)                240
#
#  relu2 (QActivation)         (None, 15)                0
#
#  encoder_output (Dense)      (None, 2)                 32
#
#  fc3 (QDense)                (None, 16)                48
#
#  relu3_dec (QActivation)     (None, 16)                0
#
#  fc4 (QDense)                (None, 32)                544
#
#  relu4 (QActivation)         (None, 32)                0
#
#  fc5 (QDense)                (None, 32)                1056
#
#  relu5 (QActivation)         (None, 32)                0
#
#  decoder_output (QDense)     (None, 64)                2112
#
#  relu_decoder (QActivation)  (None, 64)                0
#
# =================================================================
# Total params: 5,007
# Trainable params: 5,007
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/40
# 227/235 [===========================>..] - ETA: 0s - loss: 0.1277
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 1: val_loss improved from inf to 0.12062, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 1: val_loss improved from inf to 0.12062, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 1: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 1: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 22s 76ms/step - loss: 0.1275 - val_loss: 0.1206 - lr: 0.0010
# Epoch 2/40
# 234/235 [============================>.] - ETA: 0s - loss: 0.1121
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 2: val_loss improved from 0.12062 to 0.10539, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 2: val_loss improved from 0.12062 to 0.10539, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 2: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 2: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 16s 68ms/step - loss: 0.1121 - val_loss: 0.1054 - lr: 0.0010
# Epoch 3/40
# 235/235 [==============================] - ETA: 0s - loss: 0.1020
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 3: val_loss improved from 0.10539 to 0.10090, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 3: val_loss improved from 0.10539 to 0.10090, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 3: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 3: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 15s 62ms/step - loss: 0.1020 - val_loss: 0.1009 - lr: 0.0010
# Epoch 4/40
# 229/235 [============================>.] - ETA: 0s - loss: 0.0986
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 4: val_loss improved from 0.10090 to 0.09807, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 4: val_loss improved from 0.10090 to 0.09807, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 4: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 4: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 16s 68ms/step - loss: 0.0985 - val_loss: 0.0981 - lr: 0.0010
# Epoch 5/40
# 228/235 [============================>.] - ETA: 0s - loss: 0.0946
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 5: val_loss improved from 0.09807 to 0.09323, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 5: val_loss improved from 0.09807 to 0.09323, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 5: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 5: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 21s 88ms/step - loss: 0.0945 - val_loss: 0.0932 - lr: 0.0010
# Epoch 6/40
# 233/235 [============================>.] - ETA: 0s - loss: 0.0920
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 6: val_loss improved from 0.09323 to 0.09219, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 6: val_loss improved from 0.09323 to 0.09219, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 6: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 6: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 22s 96ms/step - loss: 0.0920 - val_loss: 0.0922 - lr: 0.0010
# Epoch 7/40
# 230/235 [============================>.] - ETA: 0s - loss: 0.0883
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 7: val_loss improved from 0.09219 to 0.08745, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 7: val_loss improved from 0.09219 to 0.08745, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 7: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 7: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 17s 74ms/step - loss: 0.0883 - val_loss: 0.0874 - lr: 0.0010
# Epoch 8/40
# 225/235 [===========================>..] - ETA: 0s - loss: 0.0863
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 8: val_loss improved from 0.08745 to 0.08664, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 8: val_loss improved from 0.08745 to 0.08664, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 8: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 8: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 16s 68ms/step - loss: 0.0863 - val_loss: 0.0866 - lr: 0.0010
# Epoch 9/40
# 235/235 [==============================] - ETA: 0s - loss: 0.0855
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 9: val_loss improved from 0.08664 to 0.08599, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 9: val_loss improved from 0.08664 to 0.08599, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 9: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 9: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 14s 60ms/step - loss: 0.0855 - val_loss: 0.0860 - lr: 0.0010
# Epoch 10/40
# 235/235 [==============================] - ETA: 0s - loss: 0.0825
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 10: val_loss improved from 0.08599 to 0.08173, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 10: val_loss improved from 0.08599 to 0.08173, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 10: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 10: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# Epoch 10: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_epoch10.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 14s 58ms/step - loss: 0.0825 - val_loss: 0.0817 - lr: 0.0010
# Epoch 11/40
# 226/235 [===========================>..] - ETA: 0s - loss: 0.0807
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 11: val_loss improved from 0.08173 to 0.08124, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 11: val_loss improved from 0.08173 to 0.08124, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 11: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 11: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 14s 60ms/step - loss: 0.0807 - val_loss: 0.0812 - lr: 0.0010
# Epoch 12/40
# 226/235 [===========================>..] - ETA: 0s - loss: 0.0803
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 12: val_loss improved from 0.08124 to 0.08073, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 12: val_loss improved from 0.08124 to 0.08073, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 12: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 12: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 14s 60ms/step - loss: 0.0802 - val_loss: 0.0807 - lr: 0.0010
# Epoch 13/40
# 229/235 [============================>.] - ETA: 0s - loss: 0.0788
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 13: val_loss improved from 0.08073 to 0.07918, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 13: val_loss improved from 0.08073 to 0.07918, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 13: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 13: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 15s 63ms/step - loss: 0.0788 - val_loss: 0.0792 - lr: 0.0010
# Epoch 14/40
# 235/235 [==============================] - ETA: 0s - loss: 0.0781
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 14: val_loss improved from 0.07918 to 0.07884, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 14: val_loss improved from 0.07918 to 0.07884, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 14: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 14: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 16s 68ms/step - loss: 0.0781 - val_loss: 0.0788 - lr: 0.0010
# Epoch 15/40
# 232/235 [============================>.] - ETA: 0s - loss: 0.0768
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 15: val_loss improved from 0.07884 to 0.07554, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 15: val_loss improved from 0.07884 to 0.07554, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 15: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 15: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 16s 68ms/step - loss: 0.0768 - val_loss: 0.0755 - lr: 0.0010
# Epoch 16/40
# 233/235 [============================>.] - ETA: 0s - loss: 0.0750
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 16: val_loss improved from 0.07554 to 0.07530, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 16: val_loss improved from 0.07554 to 0.07530, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 16: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 16: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 15s 62ms/step - loss: 0.0750 - val_loss: 0.0753 - lr: 0.0010
# Epoch 17/40
# 227/235 [===========================>..] - ETA: 0s - loss: 0.0747
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 17: val_loss improved from 0.07530 to 0.07481, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 17: val_loss improved from 0.07530 to 0.07481, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 17: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 17: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 15s 62ms/step - loss: 0.0747 - val_loss: 0.0748 - lr: 0.0010
# Epoch 18/40
# 226/235 [===========================>..] - ETA: 0s - loss: 0.0712
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 18: val_loss improved from 0.07481 to 0.07036, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 18: val_loss improved from 0.07481 to 0.07036, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 18: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 18: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 15s 63ms/step - loss: 0.0711 - val_loss: 0.0704 - lr: 0.0010
# Epoch 19/40
# 229/235 [============================>.] - ETA: 0s - loss: 0.0697
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 19: val_loss improved from 0.07036 to 0.07008, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 19: val_loss improved from 0.07036 to 0.07008, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 19: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 19: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 16s 67ms/step - loss: 0.0697 - val_loss: 0.0701 - lr: 0.0010
# Epoch 20/40
# 235/235 [==============================] - ETA: 0s - loss: 0.0693
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 20: val_loss improved from 0.07008 to 0.06969, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 20: val_loss improved from 0.07008 to 0.06969, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 20: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 20: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# Epoch 20: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_epoch20.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 14s 59ms/step - loss: 0.0693 - val_loss: 0.0697 - lr: 0.0010
# Epoch 21/40
# 229/235 [============================>.] - ETA: 0s - loss: 0.0690
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 21: val_loss improved from 0.06969 to 0.06958, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 21: val_loss improved from 0.06969 to 0.06958, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 21: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 21: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 16s 70ms/step - loss: 0.0690 - val_loss: 0.0696 - lr: 0.0010
# Epoch 22/40
# 229/235 [============================>.] - ETA: 0s - loss: 0.0688
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 22: val_loss improved from 0.06958 to 0.06932, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 22: val_loss improved from 0.06958 to 0.06932, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 22: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 22: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 15s 65ms/step - loss: 0.0688 - val_loss: 0.0693 - lr: 0.0010
# Epoch 23/40
# 232/235 [============================>.] - ETA: 0s - loss: 0.0686
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 23: val_loss improved from 0.06932 to 0.06901, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 23: val_loss improved from 0.06932 to 0.06901, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 23: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 23: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 15s 63ms/step - loss: 0.0686 - val_loss: 0.0690 - lr: 0.0010
# Epoch 24/40
# 233/235 [============================>.] - ETA: 0s - loss: 0.0684
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 24: val_loss improved from 0.06901 to 0.06882, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 24: val_loss improved from 0.06901 to 0.06882, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 24: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 24: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 14s 59ms/step - loss: 0.0684 - val_loss: 0.0688 - lr: 0.0010
# Epoch 25/40
# 231/235 [============================>.] - ETA: 0s - loss: 0.0683
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 25: val_loss improved from 0.06882 to 0.06864, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 25: val_loss improved from 0.06882 to 0.06864, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 25: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 25: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 13s 57ms/step - loss: 0.0683 - val_loss: 0.0686 - lr: 0.0010
# Epoch 26/40
# 233/235 [============================>.] - ETA: 0s - loss: 0.0681
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 26: val_loss improved from 0.06864 to 0.06858, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 26: val_loss improved from 0.06864 to 0.06858, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 26: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 26: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 13s 56ms/step - loss: 0.0681 - val_loss: 0.0686 - lr: 0.0010
# Epoch 27/40
# 226/235 [===========================>..] - ETA: 0s - loss: 0.0679
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 27: val_loss improved from 0.06858 to 0.06842, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 27: val_loss improved from 0.06858 to 0.06842, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 27: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 27: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 14s 58ms/step - loss: 0.0679 - val_loss: 0.0684 - lr: 0.0010
# Epoch 28/40
# 234/235 [============================>.] - ETA: 0s - loss: 0.0678
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 28: val_loss improved from 0.06842 to 0.06821, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 28: val_loss improved from 0.06842 to 0.06821, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 28: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 28: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 14s 58ms/step - loss: 0.0678 - val_loss: 0.0682 - lr: 0.0010
# Epoch 29/40
# 231/235 [============================>.] - ETA: 0s - loss: 0.0676
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 29: val_loss improved from 0.06821 to 0.06800, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 29: val_loss improved from 0.06821 to 0.06800, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 29: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 29: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 13s 54ms/step - loss: 0.0676 - val_loss: 0.0680 - lr: 0.0010
# Epoch 30/40
# 234/235 [============================>.] - ETA: 0s - loss: 0.0675
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 30: val_loss improved from 0.06800 to 0.06780, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 30: val_loss improved from 0.06800 to 0.06780, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 30: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 30: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# Epoch 30: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_epoch30.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 13s 54ms/step - loss: 0.0675 - val_loss: 0.0678 - lr: 0.0010
# Epoch 31/40
# 231/235 [============================>.] - ETA: 0s - loss: 0.0673
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 31: val_loss did not improve from 0.06780
#
# Epoch 31: val_loss did not improve from 0.06780
#
# Epoch 31: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 31: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0673 - val_loss: 0.0679 - lr: 0.0010
# Epoch 32/40
# 231/235 [============================>.] - ETA: 0s - loss: 0.0672
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 32: val_loss did not improve from 0.06780
#
# Epoch 32: val_loss did not improve from 0.06780
#
# Epoch 32: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 32: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 7s 29ms/step - loss: 0.0672 - val_loss: 0.0678 - lr: 0.0010
# Epoch 33/40
# 227/235 [===========================>..] - ETA: 0s - loss: 0.0671
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 33: val_loss improved from 0.06780 to 0.06754, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 33: val_loss improved from 0.06780 to 0.06754, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 33: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 33: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 16s 67ms/step - loss: 0.0671 - val_loss: 0.0675 - lr: 0.0010
# Epoch 34/40
# 231/235 [============================>.] - ETA: 0s - loss: 0.0670
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 34: val_loss improved from 0.06754 to 0.06746, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 34: val_loss improved from 0.06754 to 0.06746, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 34: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 34: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 12s 52ms/step - loss: 0.0670 - val_loss: 0.0675 - lr: 0.0010
# Epoch 35/40
# 225/235 [===========================>..] - ETA: 0s - loss: 0.0668
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 35: val_loss improved from 0.06746 to 0.06728, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 35: val_loss improved from 0.06746 to 0.06728, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 35: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 35: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 10s 44ms/step - loss: 0.0668 - val_loss: 0.0673 - lr: 0.0010
# Epoch 36/40
# 234/235 [============================>.] - ETA: 0s - loss: 0.0667
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 36: val_loss improved from 0.06728 to 0.06708, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 36: val_loss improved from 0.06728 to 0.06708, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 36: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 36: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 11s 45ms/step - loss: 0.0667 - val_loss: 0.0671 - lr: 0.0010
# Epoch 37/40
# 234/235 [============================>.] - ETA: 0s - loss: 0.0666
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 37: val_loss did not improve from 0.06708
#
# Epoch 37: val_loss did not improve from 0.06708
#
# Epoch 37: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 37: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 8s 33ms/step - loss: 0.0666 - val_loss: 0.0672 - lr: 0.0010
# Epoch 38/40
# 232/235 [============================>.] - ETA: 0s - loss: 0.0665
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 38: val_loss improved from 0.06708 to 0.06689, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 38: val_loss improved from 0.06708 to 0.06689, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 38: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 38: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 13s 55ms/step - loss: 0.0665 - val_loss: 0.0669 - lr: 0.0010
# Epoch 39/40
# 234/235 [============================>.] - ETA: 0s - loss: 0.0664
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 39: val_loss did not improve from 0.06689
#
# Epoch 39: val_loss did not improve from 0.06689
#
# Epoch 39: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 39: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0664 - val_loss: 0.0669 - lr: 0.0010
# Epoch 40/40
# 232/235 [============================>.] - ETA: 0s - loss: 0.0663
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 40: val_loss did not improve from 0.06689
#
# Epoch 40: val_loss did not improve from 0.06689
#
# Epoch 40: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 40: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# Epoch 40: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_epoch40.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0663 - val_loss: 0.0670 - lr: 0.0010

# %%
network.plot_latent_dimension("QAutoencoder without classifier")
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %%
network.plot_reco(model_name=" complete")
# Out:
# 313/313 [==============================] - 2s 3ms/step

# %%
network.plot_score(use_latent_classifier=False, model_name="Autoencoder without classifier")

# %%
network.plot_latent()
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %% [markdown]
# # Compressed QAE without classifier

# %%
network = QAutoencoder(data_zoom, pruned=True)
network.build_encoder()
network.build_decoder()
network.build_autoencoder()
network.fit_data(epochs=40)
network.plot_latent_dimension("Compressed QAE without classifier")
network.plot_reco(model_name=" compressed")
network.plot_score(use_latent_classifier=False,model_name="Compressed QAE without classifier")

# %% [markdown]
# # QAutoencoder with classifier

# %% [markdown]
# Repeating the same procedure for the autoencoder with classifier.

# %%
network_with_classifier = QAutoencoder(data_zoom, pruned=False)
network_with_classifier.build_encoder()
#network_with_classifier.build_decoder()
network_with_classifier.build_classifier()
network_with_classifier.build_autoencoder(use_latent_classifier=True)
network_with_classifier.fit_data( batch_size=256,epochs=40, use_latent_classifier=True)
network_with_classifier.plot_latent_dimension("QAutoencoder with classifier")
network_with_classifier.plot_score(use_latent_classifier=True,model_name="QAutoencoder with classifier")

# %% [markdown]
# ### Quantized only classifier

# %%
network_with_classifier = QAutoencoder(data_zoom, pruned=True)
network_with_classifier.build_encoder()
network_with_classifier.build_decoder()
network_with_classifier.build_classifier()
network_with_classifier.build_autoencoder(use_latent_classifier=True)
network_with_classifier.fit_data(epochs=40,use_latent_classifier=True)
network_with_classifier.plot_latent_dimension("Compressed QAE with classifier")
network_with_classifier.plot_score(use_latent_classifier=True,model_name="Compressed QAE with classifier")

# %% [markdown]
# ### Import the QAutoencoder class & MNIST data class and call it

# %%
# file class_QAutoencoder.py
from class_QAutoencoder import *
import MNIST_database as mnist

# %% [markdown]
# Original dataset and modified dataset with modifiable resolution is shown below.

# %%
# import MNIST_dataset as mnist
# size_final = 28

# data = mnist.MNISTData(size_initial=28, size_final=size_final, color_depth=8)
# train= data.x_train
# ax = plt.subplot(1, 1 , 1)

# plt.imshow(train[0].reshape(size_final,size_final), cmap='gray_r')
# ax.get_xaxis().set_visible(False)
# ax.get_yaxis().set_visible(False)

# %%
#Choose the final size of your image dataset
size_final = 8

# data_zoom = mnist.MNISTData(size_initial=20, size_final=size_final, color_depth=5, flat=True)
data_zoom = mnist.MNISTData(size_initial=20, size_final=8, color_depth=8, flat=True)

train= data_zoom.x_train
ax = plt.subplot(1, 1 , 1)

plt.imshow(train[0].reshape(size_final,size_final), cmap='gray_r')
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)

# %% [markdown]
# # Autoencoder using Keras
# The aim of this class is to implement a simple autoencoder for the MNIST data and then build an autoencoder that is
# able to classify MNIST data in its latent dimension.
#
# Code partially adapted from [Keras Documentation](https://blog.keras.io/building-autoencoders-in-keras.html).

# %%
BIT_WIDTH = 8

# %% [markdown]
# # QAutoencoder without classifier

# %% [markdown]
# It is built the standard autoencoder, *without classifier* here, and the MNIST data class called before is used.
# The model is fitted and adequate plots are reproduced,
# as well as the comparison between orginal MNIST dataset and reconstructed images.

# %%
network = QAutoencoder(data_zoom, pruned=False, BIT_WIDTH = BIT_WIDTH)
network.build_encoder()
network.build_decoder()
network.build_autoencoder()
network.fit_data(epochs=40)
network.plot_latent_dimension("QAutoencoder without classifier")
network.plot_reco(model_name=" complete")
network.plot_score(use_latent_classifier=False, model_name="Autoencoder without classifier")
network.plot_latent()
# Out:
# Model: "autoencoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  encoder_input (InputLayer)  [(None, 64)]              0
#
#  fc1 (QDense)                (None, 15)                975
#
#  relu1 (QActivation)         (None, 15)                0
#
#  fc2 (QDense)                (None, 15)                240
#
#  relu2 (QActivation)         (None, 15)                0
#
#  encoder_output (Dense)      (None, 2)                 32
#
#  fc3 (QDense)                (None, 16)                48
#
#  relu3_dec (QActivation)     (None, 16)                0
#
#  fc4 (QDense)                (None, 32)                544
#
#  relu4 (QActivation)         (None, 32)                0
#
#  fc5 (QDense)                (None, 32)                1056
#
#  relu5 (QActivation)         (None, 32)                0
#
#  decoder_output (QDense)     (None, 64)                2112
#
#  relu_decoder (QActivation)  (None, 64)                0
#
# =================================================================
# Total params: 5,007
# Trainable params: 5,007
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/40
# 232/235 [============================>.] - ETA: 0s - loss: 0.1256
# ***callbacks***
# saving losses to model/QAE_model8bits/model_2\losses.log
#
# Epoch 1: val_loss improved from inf to 0.12226, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 1: val_loss improved from inf to 0.12226, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 1: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 1: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 23s 75ms/step - loss: 0.1256 - val_loss: 0.1223 - lr: 0.0010
# Epoch 2/40
# 227/235 [===========================>..] - ETA: 0s - loss: 0.1162
# ***callbacks***
# saving losses to model/QAE_model8bits/model_2\losses.log
#
# Epoch 2: val_loss improved from 0.12226 to 0.11075, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 2: val_loss improved from 0.12226 to 0.11075, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 2: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 2: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 15s 62ms/step - loss: 0.1161 - val_loss: 0.1108 - lr: 0.0010
# Epoch 3/40
# 235/235 [==============================] - ETA: 0s - loss: 0.1078
# ***callbacks***
# saving losses to model/QAE_model8bits/model_2\losses.log
#
# Epoch 3: val_loss improved from 0.11075 to 0.10727, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 3: val_loss improved from 0.11075 to 0.10727, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 3: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 3: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 14s 58ms/step - loss: 0.1078 - val_loss: 0.1073 - lr: 0.0010
# Epoch 4/40
# 229/235 [============================>.] - ETA: 0s - loss: 0.1060
# ***callbacks***
# saving losses to model/QAE_model8bits/model_2\losses.log
#
# Epoch 4: val_loss improved from 0.10727 to 0.10667, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 4: val_loss improved from 0.10727 to 0.10667, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 4: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 4: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 15s 64ms/step - loss: 0.1060 - val_loss: 0.1067 - lr: 0.0010
# Epoch 5/40
# 227/235 [===========================>..] - ETA: 0s - loss: 0.1056
# ***callbacks***
# saving losses to model/QAE_model8bits/model_2\losses.log
#
# Epoch 5: val_loss improved from 0.10667 to 0.10630, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 5: val_loss improved from 0.10667 to 0.10630, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 5: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 5: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 15s 64ms/step - loss: 0.1056 - val_loss: 0.1063 - lr: 0.0010
# Epoch 6/40
# 235/235 [==============================] - ETA: 0s - loss: 0.1050
# ***callbacks***
# saving losses to model/QAE_model8bits/model_2\losses.log
#
# Epoch 6: val_loss improved from 0.10630 to 0.10504, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 6: val_loss improved from 0.10630 to 0.10504, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 6: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 6: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 18s 78ms/step - loss: 0.1050 - val_loss: 0.1050 - lr: 0.0010
# Epoch 7/40
# 230/235 [============================>.] - ETA: 0s - loss: 0.0988
# ***callbacks***
# saving losses to model/QAE_model8bits/model_2\losses.log
#
# Epoch 7: val_loss improved from 0.10504 to 0.09221, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 7: val_loss improved from 0.10504 to 0.09221, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 7: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 7: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 22s 92ms/step - loss: 0.0986 - val_loss: 0.0922 - lr: 0.0010
# Epoch 8/40
# 233/235 [============================>.] - ETA: 0s - loss: 0.0906
# ***callbacks***
# saving losses to model/QAE_model8bits/model_2\losses.log
#
# Epoch 8: val_loss improved from 0.09221 to 0.08945, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 8: val_loss improved from 0.09221 to 0.08945, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 8: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 8: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 16s 66ms/step - loss: 0.0906 - val_loss: 0.0895 - lr: 0.0010
# Epoch 9/40
# 228/235 [============================>.] - ETA: 0s - loss: 0.0887
# ***callbacks***
# saving losses to model/QAE_model8bits/model_2\losses.log
#
# Epoch 9: val_loss improved from 0.08945 to 0.08810, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 9: val_loss improved from 0.08945 to 0.08810, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 9: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 9: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 17s 71ms/step - loss: 0.0887 - val_loss: 0.0881 - lr: 0.0010
# Epoch 10/40
# 234/235 [============================>.] - ETA: 0s - loss: 0.0869
# ***callbacks***
# saving losses to model/QAE_model8bits/model_2\losses.log
#
# Epoch 10: val_loss improved from 0.08810 to 0.08596, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 10: val_loss improved from 0.08810 to 0.08596, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 10: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 10: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last_weights.h5
#
# Epoch 10: saving model to model/QAE_model8bits/model_2\KERAS_check_model_epoch10.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 19s 83ms/step - loss: 0.0869 - val_loss: 0.0860 - lr: 0.0010
# Epoch 11/40
# 234/235 [============================>.] - ETA: 0s - loss: 0.0849
# ***callbacks***
# saving losses to model/QAE_model8bits/model_2\losses.log
#
# Epoch 11: val_loss improved from 0.08596 to 0.08409, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 11: val_loss improved from 0.08596 to 0.08409, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 11: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 11: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 18s 75ms/step - loss: 0.0849 - val_loss: 0.0841 - lr: 0.0010
# Epoch 12/40
# 227/235 [===========================>..] - ETA: 0s - loss: 0.0816
# ***callbacks***
# saving losses to model/QAE_model8bits/model_2\losses.log
#
# Epoch 12: val_loss improved from 0.08409 to 0.07821, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 12: val_loss improved from 0.08409 to 0.07821, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 12: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 12: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 16s 67ms/step - loss: 0.0815 - val_loss: 0.0782 - lr: 0.0010
# Epoch 13/40
# 232/235 [============================>.] - ETA: 0s - loss: 0.0777
# ***callbacks***
# saving losses to model/QAE_model8bits/model_2\losses.log
#
# Epoch 13: val_loss improved from 0.07821 to 0.07709, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 13: val_loss improved from 0.07821 to 0.07709, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 13: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 13: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 14s 60ms/step - loss: 0.0777 - val_loss: 0.0771 - lr: 0.0010
# Epoch 14/40
# 229/235 [============================>.] - ETA: 0s - loss: 0.0768
# ***callbacks***
# saving losses to model/QAE_model8bits/model_2\losses.log
#
# Epoch 14: val_loss improved from 0.07709 to 0.07650, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 14: val_loss improved from 0.07709 to 0.07650, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 14: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 14: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 14s 59ms/step - loss: 0.0769 - val_loss: 0.0765 - lr: 0.0010
# Epoch 15/40
# 234/235 [============================>.] - ETA: 0s - loss: 0.0763
# ***callbacks***
# saving losses to model/QAE_model8bits/model_2\losses.log
#
# Epoch 15: val_loss improved from 0.07650 to 0.07609, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 15: val_loss improved from 0.07650 to 0.07609, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 15: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 15: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 26s 111ms/step - loss: 0.0763 - val_loss: 0.0761 - lr: 0.0010
# Epoch 16/40
# 228/235 [============================>.] - ETA: 0s - loss: 0.0759
# ***callbacks***
# saving losses to model/QAE_model8bits/model_2\losses.log
#
# Epoch 16: val_loss improved from 0.07609 to 0.07557, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 16: val_loss improved from 0.07609 to 0.07557, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 16: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 16: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 16s 69ms/step - loss: 0.0758 - val_loss: 0.0756 - lr: 0.0010
# Epoch 17/40
# 231/235 [============================>.] - ETA: 0s - loss: 0.0755
# ***callbacks***
# saving losses to model/QAE_model8bits/model_2\losses.log
#
# Epoch 17: val_loss improved from 0.07557 to 0.07535, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 17: val_loss improved from 0.07557 to 0.07535, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 17: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 17: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 16s 70ms/step - loss: 0.0755 - val_loss: 0.0754 - lr: 0.0010
# Epoch 18/40
# 234/235 [============================>.] - ETA: 0s - loss: 0.0748
# ***callbacks***
# saving losses to model/QAE_model8bits/model_2\losses.log
#
# Epoch 18: val_loss improved from 0.07535 to 0.07280, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 18: val_loss improved from 0.07535 to 0.07280, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 18: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 18: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 16s 69ms/step - loss: 0.0748 - val_loss: 0.0728 - lr: 0.0010
# Epoch 19/40
# 230/235 [============================>.] - ETA: 0s - loss: 0.0724
# ***callbacks***
# saving losses to model/QAE_model8bits/model_2\losses.log
#
# Epoch 19: val_loss improved from 0.07280 to 0.07238, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 19: val_loss improved from 0.07280 to 0.07238, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 19: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 19: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 22s 94ms/step - loss: 0.0724 - val_loss: 0.0724 - lr: 0.0010
# Epoch 20/40
# 232/235 [============================>.] - ETA: 0s - loss: 0.0721
# ***callbacks***
# saving losses to model/QAE_model8bits/model_2\losses.log
#
# Epoch 20: val_loss improved from 0.07238 to 0.07190, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 20: val_loss improved from 0.07238 to 0.07190, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 20: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 20: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last_weights.h5
#
# Epoch 20: saving model to model/QAE_model8bits/model_2\KERAS_check_model_epoch20.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 18s 77ms/step - loss: 0.0720 - val_loss: 0.0719 - lr: 0.0010
# Epoch 21/40
# 233/235 [============================>.] - ETA: 0s - loss: 0.0717
# ***callbacks***
# saving losses to model/QAE_model8bits/model_2\losses.log
#
# Epoch 21: val_loss did not improve from 0.07190
#
# Epoch 21: val_loss did not improve from 0.07190
#
# Epoch 21: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 21: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 9s 37ms/step - loss: 0.0717 - val_loss: 0.0719 - lr: 0.0010
# Epoch 22/40
# 234/235 [============================>.] - ETA: 0s - loss: 0.0715
# ***callbacks***
# saving losses to model/QAE_model8bits/model_2\losses.log
#
# Epoch 22: val_loss improved from 0.07190 to 0.07133, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 22: val_loss improved from 0.07190 to 0.07133, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 22: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 22: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 19s 82ms/step - loss: 0.0715 - val_loss: 0.0713 - lr: 0.0010
# Epoch 23/40
# 234/235 [============================>.] - ETA: 0s - loss: 0.0712
# ***callbacks***
# saving losses to model/QAE_model8bits/model_2\losses.log
#
# Epoch 23: val_loss improved from 0.07133 to 0.07127, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 23: val_loss improved from 0.07133 to 0.07127, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 23: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 23: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 26s 110ms/step - loss: 0.0712 - val_loss: 0.0713 - lr: 0.0010
# Epoch 24/40
# 230/235 [============================>.] - ETA: 0s - loss: 0.0710
# ***callbacks***
# saving losses to model/QAE_model8bits/model_2\losses.log
#
# Epoch 24: val_loss improved from 0.07127 to 0.07099, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 24: val_loss improved from 0.07127 to 0.07099, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 24: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 24: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 19s 82ms/step - loss: 0.0710 - val_loss: 0.0710 - lr: 0.0010
# Epoch 25/40
# 230/235 [============================>.] - ETA: 0s - loss: 0.0707
# ***callbacks***
# saving losses to model/QAE_model8bits/model_2\losses.log
#
# Epoch 25: val_loss improved from 0.07099 to 0.07069, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 25: val_loss improved from 0.07099 to 0.07069, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 25: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 25: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 17s 71ms/step - loss: 0.0706 - val_loss: 0.0707 - lr: 0.0010
# Epoch 26/40
# 235/235 [==============================] - ETA: 0s - loss: 0.0704
# ***callbacks***
# saving losses to model/QAE_model8bits/model_2\losses.log
#
# Epoch 26: val_loss improved from 0.07069 to 0.07056, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 26: val_loss improved from 0.07069 to 0.07056, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 26: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 26: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 14s 61ms/step - loss: 0.0704 - val_loss: 0.0706 - lr: 0.0010
# Epoch 27/40
# 229/235 [============================>.] - ETA: 0s - loss: 0.0703
# ***callbacks***
# saving losses to model/QAE_model8bits/model_2\losses.log
#
# Epoch 27: val_loss improved from 0.07056 to 0.07045, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 27: val_loss improved from 0.07056 to 0.07045, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 27: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 27: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 14s 60ms/step - loss: 0.0703 - val_loss: 0.0705 - lr: 0.0010
# Epoch 28/40
# 228/235 [============================>.] - ETA: 0s - loss: 0.0701
# ***callbacks***
# saving losses to model/QAE_model8bits/model_2\losses.log
#
# Epoch 28: val_loss improved from 0.07045 to 0.07021, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 28: val_loss improved from 0.07045 to 0.07021, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 28: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 28: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 15s 64ms/step - loss: 0.0701 - val_loss: 0.0702 - lr: 0.0010
# Epoch 29/40
# 230/235 [============================>.] - ETA: 0s - loss: 0.0700
# ***callbacks***
# saving losses to model/QAE_model8bits/model_2\losses.log
#
# Epoch 29: val_loss did not improve from 0.07021
#
# Epoch 29: val_loss did not improve from 0.07021
#
# Epoch 29: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 29: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 10s 44ms/step - loss: 0.0700 - val_loss: 0.0702 - lr: 0.0010
# Epoch 30/40
# 227/235 [===========================>..] - ETA: 0s - loss: 0.0699
# ***callbacks***
# saving losses to model/QAE_model8bits/model_2\losses.log
#
# Epoch 30: val_loss improved from 0.07021 to 0.06997, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 30: val_loss improved from 0.07021 to 0.06997, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 30: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 30: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last_weights.h5
#
# Epoch 30: saving model to model/QAE_model8bits/model_2\KERAS_check_model_epoch30.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 14s 61ms/step - loss: 0.0698 - val_loss: 0.0700 - lr: 0.0010
# Epoch 31/40
# 232/235 [============================>.] - ETA: 0s - loss: 0.0696
# ***callbacks***
# saving losses to model/QAE_model8bits/model_2\losses.log
#
# Epoch 31: val_loss improved from 0.06997 to 0.06979, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 31: val_loss improved from 0.06997 to 0.06979, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 31: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 31: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 14s 61ms/step - loss: 0.0696 - val_loss: 0.0698 - lr: 0.0010
# Epoch 32/40
# 233/235 [============================>.] - ETA: 0s - loss: 0.0696
# ***callbacks***
# saving losses to model/QAE_model8bits/model_2\losses.log
#
# Epoch 32: val_loss improved from 0.06979 to 0.06968, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 32: val_loss improved from 0.06979 to 0.06968, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 32: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 32: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 14s 60ms/step - loss: 0.0695 - val_loss: 0.0697 - lr: 0.0010
# Epoch 33/40
# 228/235 [============================>.] - ETA: 0s - loss: 0.0695
# ***callbacks***
# saving losses to model/QAE_model8bits/model_2\losses.log
#
# Epoch 33: val_loss improved from 0.06968 to 0.06965, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 33: val_loss improved from 0.06968 to 0.06965, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 33: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 33: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 15s 63ms/step - loss: 0.0694 - val_loss: 0.0697 - lr: 0.0010
# Epoch 34/40
# 227/235 [===========================>..] - ETA: 0s - loss: 0.0693
# ***callbacks***
# saving losses to model/QAE_model8bits/model_2\losses.log
#
# Epoch 34: val_loss improved from 0.06965 to 0.06951, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 34: val_loss improved from 0.06965 to 0.06951, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 34: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 34: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 17s 72ms/step - loss: 0.0693 - val_loss: 0.0695 - lr: 0.0010
# Epoch 35/40
# 230/235 [============================>.] - ETA: 0s - loss: 0.0692
# ***callbacks***
# saving losses to model/QAE_model8bits/model_2\losses.log
#
# Epoch 35: val_loss improved from 0.06951 to 0.06936, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 35: val_loss improved from 0.06951 to 0.06936, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 35: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 35: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 16s 68ms/step - loss: 0.0692 - val_loss: 0.0694 - lr: 0.0010
# Epoch 36/40
# 234/235 [============================>.] - ETA: 0s - loss: 0.0691
# ***callbacks***
# saving losses to model/QAE_model8bits/model_2\losses.log
#
# Epoch 36: val_loss improved from 0.06936 to 0.06926, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 36: val_loss improved from 0.06936 to 0.06926, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 36: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 36: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 17s 72ms/step - loss: 0.0691 - val_loss: 0.0693 - lr: 0.0010
# Epoch 37/40
# 233/235 [============================>.] - ETA: 0s - loss: 0.0690
# ***callbacks***
# saving losses to model/QAE_model8bits/model_2\losses.log
#
# Epoch 37: val_loss improved from 0.06926 to 0.06925, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 37: val_loss improved from 0.06926 to 0.06925, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 37: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 37: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 16s 67ms/step - loss: 0.0690 - val_loss: 0.0692 - lr: 0.0010
# Epoch 38/40
# 229/235 [============================>.] - ETA: 0s - loss: 0.0689
# ***callbacks***
# saving losses to model/QAE_model8bits/model_2\losses.log
#
# Epoch 38: val_loss did not improve from 0.06925
#
# Epoch 38: val_loss did not improve from 0.06925
#
# Epoch 38: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 38: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 7s 32ms/step - loss: 0.0689 - val_loss: 0.0693 - lr: 0.0010
# Epoch 39/40
# 233/235 [============================>.] - ETA: 0s - loss: 0.0688
# ***callbacks***
# saving losses to model/QAE_model8bits/model_2\losses.log
#
# Epoch 39: val_loss improved from 0.06925 to 0.06910, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 39: val_loss improved from 0.06925 to 0.06910, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 39: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 39: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 22s 96ms/step - loss: 0.0688 - val_loss: 0.0691 - lr: 0.0010
# Epoch 40/40
# 235/235 [==============================] - ETA: 0s - loss: 0.0687
# ***callbacks***
# saving losses to model/QAE_model8bits/model_2\losses.log
#
# Epoch 40: val_loss improved from 0.06910 to 0.06895, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 40: val_loss improved from 0.06910 to 0.06895, saving model to model/QAE_model8bits/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 40: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 40: saving model to model/QAE_model8bits/model_2\KERAS_check_model_last_weights.h5
#
# Epoch 40: saving model to model/QAE_model8bits/model_2\KERAS_check_model_epoch40.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 21s 88ms/step - loss: 0.0687 - val_loss: 0.0689 - lr: 0.0010
# 313/313 [==============================] - 1s 2ms/step
# 313/313 [==============================] - 2s 3ms/step
# 313/313 [==============================] - 1s 2ms/step

# %% [markdown]
# # Compressed QAE without classifier

# %%
network = QAutoencoder(data_zoom, pruned=True)
network.build_encoder()
network.build_decoder()
network.build_autoencoder()
network.fit_data(epochs=40)
network.plot_latent_dimension("Compressed QAE without classifier")
network.plot_reco(model_name=" compressed")
network.plot_score(use_latent_classifier=False,model_name="Compressed QAE without classifier")

# %% [markdown]
# # QAutoencoder with classifier

# %% [markdown]
# Repeating the same procedure for the autoencoder with classifier.

# %%
network_with_classifier = QAutoencoder(data_zoom, pruned=False)
network_with_classifier.build_encoder()
#network_with_classifier.build_decoder()
network_with_classifier.build_classifier()
network_with_classifier.build_autoencoder(use_latent_classifier=True)
network_with_classifier.fit_data( batch_size=256,epochs=40, use_latent_classifier=True)
network_with_classifier.plot_latent_dimension("QAutoencoder with classifier")
network_with_classifier.plot_score(use_latent_classifier=True,model_name="QAutoencoder with classifier")

# %% [markdown]
# ### Quantized only classifier

# %%
network_with_classifier = QAutoencoder(data_zoom, pruned=True)
network_with_classifier.build_encoder()
network_with_classifier.build_decoder()
network_with_classifier.build_classifier()
network_with_classifier.build_autoencoder(use_latent_classifier=True)
network_with_classifier.fit_data(epochs=40,use_latent_classifier=True)
network_with_classifier.plot_latent_dimension("Compressed QAE with classifier")
network_with_classifier.plot_score(use_latent_classifier=True,model_name="Compressed QAE with classifier")

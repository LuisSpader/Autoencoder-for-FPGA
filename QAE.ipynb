# %% [markdown]
# ### Import the QAutoencoder class & MNIST data class and call it

# %%
# file class_QAutoencoder.py
from class_QAutoencoder import *
# from class_QAutoencoder_mini import *
import MNIST_database as mnist

# %% [markdown]
# Original dataset and modified dataset with modifiable resolution is shown below.

# %%
# import MNIST_dataset as mnist
# size_final = 28

# data = mnist.MNISTData(size_initial=28, size_final=size_final, color_depth=8)
# train= data.x_train
# ax = plt.subplot(1, 1 , 1)

# plt.imshow(train[0].reshape(size_final,size_final), cmap='gray_r')
# ax.get_xaxis().set_visible(False)
# ax.get_yaxis().set_visible(False)

# %%
#Choose the final size of your image dataset
size_final = 8

# data_zoom = mnist.MNISTData(size_initial=20, size_final=size_final, color_depth=5, flat=True)
data_zoom = mnist.MNISTData(size_initial=20, size_final=8, color_depth=8, flat=True)

train= data_zoom.x_train
ax = plt.subplot(1, 1 , 1)

plt.imshow(train[0].reshape(size_final,size_final), cmap='gray_r')
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)

# %% [markdown]
# # Autoencoder using Keras
# The aim of this class is to implement a simple autoencoder for the MNIST data and then build an autoencoder that is
# able to classify MNIST data in its latent dimension.
#
# Code partially adapted from [Keras Documentation](https://blog.keras.io/building-autoencoders-in-keras.html).

# %%
BIT_WIDTH = 8

# %% [markdown]
# # QAutoencoder without classifier

# %% [markdown]
# It is built the standard autoencoder, *without classifier* here, and the MNIST data class called before is used.
# The model is fitted and adequate plots are reproduced,
# as well as the comparison between orginal MNIST dataset and reconstructed images.

# %%
network = QAutoencoder(data_zoom, pruned=False, BIT_WIDTH = BIT_WIDTH)
network.build_encoder()
network.build_decoder()
network.build_autoencoder()
network.fit_data(epochs=40)
network.plot_latent_dimension("QAutoencoder without classifier")
network.plot_reco(model_name=" complete")
network.plot_score(use_latent_classifier=False, model_name="Autoencoder without classifier")
network.plot_latent()
# Out:
# Model: "autoencoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  encoder_input (InputLayer)  [(None, 64)]              0
#
#  fc1 (QDense)                (None, 15)                975
#
#  relu1 (QActivation)         (None, 15)                0
#
#  fc2 (QDense)                (None, 15)                240
#
#  relu2 (QActivation)         (None, 15)                0
#
#  encoder_output (Dense)      (None, 2)                 32
#
#  fc3 (QDense)                (None, 16)                48
#
#  relu3_dec (QActivation)     (None, 16)                0
#
#  fc4 (QDense)                (None, 32)                544
#
#  relu4 (QActivation)         (None, 32)                0
#
#  fc5 (QDense)                (None, 32)                1056
#
#  relu5 (QActivation)         (None, 32)                0
#
#  decoder_output (QDense)     (None, 64)                2112
#
#  relu_decoder (QActivation)  (None, 64)                0
#
# =================================================================
# Total params: 5,007
# Trainable params: 5,007
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/40
# 232/235 [============================>.] - ETA: 0s - loss: 0.1226
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 1: val_loss improved from inf to 0.10958, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 1: val_loss improved from inf to 0.10958, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 1: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 1: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 20s 63ms/step - loss: 0.1224 - val_loss: 0.1096 - lr: 0.0010
# Epoch 2/40
# 234/235 [============================>.] - ETA: 0s - loss: 0.1042
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 2: val_loss improved from 0.10958 to 0.09737, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 2: val_loss improved from 0.10958 to 0.09737, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 2: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 2: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 16s 69ms/step - loss: 0.1042 - val_loss: 0.0974 - lr: 0.0010
# Epoch 3/40
# 228/235 [============================>.] - ETA: 0s - loss: 0.0939
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 3: val_loss improved from 0.09737 to 0.09275, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 3: val_loss improved from 0.09737 to 0.09275, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 3: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 3: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 16s 68ms/step - loss: 0.0939 - val_loss: 0.0928 - lr: 0.0010
# Epoch 4/40
# 233/235 [============================>.] - ETA: 0s - loss: 0.0850
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 4: val_loss improved from 0.09275 to 0.07903, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 4: val_loss improved from 0.09275 to 0.07903, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 4: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 4: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 16s 68ms/step - loss: 0.0849 - val_loss: 0.0790 - lr: 0.0010
# Epoch 5/40
# 230/235 [============================>.] - ETA: 0s - loss: 0.0779
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 5: val_loss improved from 0.07903 to 0.07730, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 5: val_loss improved from 0.07903 to 0.07730, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 5: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 5: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 20s 85ms/step - loss: 0.0779 - val_loss: 0.0773 - lr: 0.0010
# Epoch 6/40
# 233/235 [============================>.] - ETA: 0s - loss: 0.0765
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 6: val_loss improved from 0.07730 to 0.07587, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 6: val_loss improved from 0.07730 to 0.07587, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 6: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 6: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 22s 92ms/step - loss: 0.0765 - val_loss: 0.0759 - lr: 0.0010
# Epoch 7/40
# 229/235 [============================>.] - ETA: 0s - loss: 0.0753
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 7: val_loss improved from 0.07587 to 0.07474, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 7: val_loss improved from 0.07587 to 0.07474, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 7: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 7: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 16s 70ms/step - loss: 0.0753 - val_loss: 0.0747 - lr: 0.0010
# Epoch 8/40
# 232/235 [============================>.] - ETA: 0s - loss: 0.0742
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 8: val_loss improved from 0.07474 to 0.07393, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 8: val_loss improved from 0.07474 to 0.07393, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 8: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 8: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 16s 70ms/step - loss: 0.0742 - val_loss: 0.0739 - lr: 0.0010
# Epoch 9/40
# 229/235 [============================>.] - ETA: 0s - loss: 0.0734
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 9: val_loss improved from 0.07393 to 0.07326, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 9: val_loss improved from 0.07393 to 0.07326, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 9: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 9: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 15s 65ms/step - loss: 0.0734 - val_loss: 0.0733 - lr: 0.0010
# Epoch 10/40
# 227/235 [===========================>..] - ETA: 0s - loss: 0.0727
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 10: val_loss improved from 0.07326 to 0.07265, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 10: val_loss improved from 0.07326 to 0.07265, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 10: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 10: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# Epoch 10: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_epoch10.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 15s 64ms/step - loss: 0.0727 - val_loss: 0.0727 - lr: 0.0010
# Epoch 11/40
# 235/235 [==============================] - ETA: 0s - loss: 0.0720
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 11: val_loss improved from 0.07265 to 0.07178, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 11: val_loss improved from 0.07265 to 0.07178, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 11: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 11: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 17s 71ms/step - loss: 0.0720 - val_loss: 0.0718 - lr: 0.0010
# Epoch 12/40
# 227/235 [===========================>..] - ETA: 0s - loss: 0.0713
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 12: val_loss improved from 0.07178 to 0.07131, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 12: val_loss improved from 0.07178 to 0.07131, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 12: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 12: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 14s 61ms/step - loss: 0.0714 - val_loss: 0.0713 - lr: 0.0010
# Epoch 13/40
# 227/235 [===========================>..] - ETA: 0s - loss: 0.0709
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 13: val_loss improved from 0.07131 to 0.07103, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 13: val_loss improved from 0.07131 to 0.07103, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 13: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 13: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 20s 85ms/step - loss: 0.0709 - val_loss: 0.0710 - lr: 0.0010
# Epoch 14/40
# 231/235 [============================>.] - ETA: 0s - loss: 0.0705
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 14: val_loss improved from 0.07103 to 0.07046, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 14: val_loss improved from 0.07103 to 0.07046, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 14: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 14: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 16s 70ms/step - loss: 0.0705 - val_loss: 0.0705 - lr: 0.0010
# Epoch 15/40
# 230/235 [============================>.] - ETA: 0s - loss: 0.0702
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 15: val_loss improved from 0.07046 to 0.07020, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 15: val_loss improved from 0.07046 to 0.07020, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 15: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 15: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 20s 85ms/step - loss: 0.0702 - val_loss: 0.0702 - lr: 0.0010
# Epoch 16/40
# 231/235 [============================>.] - ETA: 0s - loss: 0.0699
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 16: val_loss improved from 0.07020 to 0.06986, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 16: val_loss improved from 0.07020 to 0.06986, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 16: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 16: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 27s 116ms/step - loss: 0.0699 - val_loss: 0.0699 - lr: 0.0010
# Epoch 17/40
# 228/235 [============================>.] - ETA: 0s - loss: 0.0696
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 17: val_loss improved from 0.06986 to 0.06974, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 17: val_loss improved from 0.06986 to 0.06974, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 17: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 17: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 25s 109ms/step - loss: 0.0696 - val_loss: 0.0697 - lr: 0.0010
# Epoch 18/40
# 229/235 [============================>.] - ETA: 0s - loss: 0.0693
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 18: val_loss improved from 0.06974 to 0.06938, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 18: val_loss improved from 0.06974 to 0.06938, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 18: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 18: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 20s 84ms/step - loss: 0.0693 - val_loss: 0.0694 - lr: 0.0010
# Epoch 19/40
# 233/235 [============================>.] - ETA: 0s - loss: 0.0691
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 19: val_loss improved from 0.06938 to 0.06924, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 19: val_loss improved from 0.06938 to 0.06924, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 19: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 19: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 58s 249ms/step - loss: 0.0691 - val_loss: 0.0692 - lr: 0.0010
# Epoch 20/40
# 234/235 [============================>.] - ETA: 0s - loss: 0.0689
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 20: val_loss improved from 0.06924 to 0.06901, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 20: val_loss improved from 0.06924 to 0.06901, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 20: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 20: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# Epoch 20: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_epoch20.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 31s 132ms/step - loss: 0.0689 - val_loss: 0.0690 - lr: 0.0010
# Epoch 21/40
# 230/235 [============================>.] - ETA: 0s - loss: 0.0686
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 21: val_loss improved from 0.06901 to 0.06877, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 21: val_loss improved from 0.06901 to 0.06877, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 21: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 21: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 19s 81ms/step - loss: 0.0686 - val_loss: 0.0688 - lr: 0.0010
# Epoch 22/40
# 234/235 [============================>.] - ETA: 0s - loss: 0.0684
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 22: val_loss improved from 0.06877 to 0.06846, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 22: val_loss improved from 0.06877 to 0.06846, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 22: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 22: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 17s 72ms/step - loss: 0.0684 - val_loss: 0.0685 - lr: 0.0010
# Epoch 23/40
# 230/235 [============================>.] - ETA: 0s - loss: 0.0682
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 23: val_loss improved from 0.06846 to 0.06829, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 23: val_loss improved from 0.06846 to 0.06829, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 23: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 23: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 19s 82ms/step - loss: 0.0682 - val_loss: 0.0683 - lr: 0.0010
# Epoch 24/40
# 227/235 [===========================>..] - ETA: 0s - loss: 0.0680
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 24: val_loss did not improve from 0.06829
#
# Epoch 24: val_loss did not improve from 0.06829
#
# Epoch 24: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 24: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 9s 40ms/step - loss: 0.0680 - val_loss: 0.0684 - lr: 0.0010
# Epoch 25/40
# 230/235 [============================>.] - ETA: 0s - loss: 0.0679
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 25: val_loss improved from 0.06829 to 0.06803, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 25: val_loss improved from 0.06829 to 0.06803, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 25: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 25: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 17s 75ms/step - loss: 0.0679 - val_loss: 0.0680 - lr: 0.0010
# Epoch 26/40
# 233/235 [============================>.] - ETA: 0s - loss: 0.0678
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 26: val_loss improved from 0.06803 to 0.06790, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 26: val_loss improved from 0.06803 to 0.06790, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 26: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 26: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 23s 97ms/step - loss: 0.0678 - val_loss: 0.0679 - lr: 0.0010
# Epoch 27/40
# 229/235 [============================>.] - ETA: 0s - loss: 0.0676
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 27: val_loss improved from 0.06790 to 0.06780, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 27: val_loss improved from 0.06790 to 0.06780, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 27: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 27: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 17s 71ms/step - loss: 0.0676 - val_loss: 0.0678 - lr: 0.0010
# Epoch 28/40
# 232/235 [============================>.] - ETA: 0s - loss: 0.0675
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 28: val_loss did not improve from 0.06780
#
# Epoch 28: val_loss did not improve from 0.06780
#
# Epoch 28: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 28: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 8s 34ms/step - loss: 0.0675 - val_loss: 0.0679 - lr: 0.0010
# Epoch 29/40
# 231/235 [============================>.] - ETA: 0s - loss: 0.0674
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 29: val_loss improved from 0.06780 to 0.06758, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 29: val_loss improved from 0.06780 to 0.06758, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 29: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 29: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 14s 60ms/step - loss: 0.0674 - val_loss: 0.0676 - lr: 0.0010
# Epoch 30/40
# 228/235 [============================>.] - ETA: 0s - loss: 0.0673
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 30: val_loss improved from 0.06758 to 0.06748, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 30: val_loss improved from 0.06758 to 0.06748, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 30: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 30: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# Epoch 30: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_epoch30.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 15s 62ms/step - loss: 0.0672 - val_loss: 0.0675 - lr: 0.0010
# Epoch 31/40
# 234/235 [============================>.] - ETA: 0s - loss: 0.0672
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 31: val_loss improved from 0.06748 to 0.06746, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 31: val_loss improved from 0.06748 to 0.06746, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 31: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 31: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 14s 60ms/step - loss: 0.0672 - val_loss: 0.0675 - lr: 0.0010
# Epoch 32/40
# 234/235 [============================>.] - ETA: 0s - loss: 0.0671
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 32: val_loss improved from 0.06746 to 0.06737, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 32: val_loss improved from 0.06746 to 0.06737, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 32: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 32: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 14s 59ms/step - loss: 0.0672 - val_loss: 0.0674 - lr: 0.0010
# Epoch 33/40
# 234/235 [============================>.] - ETA: 0s - loss: 0.0670
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 33: val_loss improved from 0.06737 to 0.06722, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 33: val_loss improved from 0.06737 to 0.06722, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 33: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 33: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 15s 63ms/step - loss: 0.0670 - val_loss: 0.0672 - lr: 0.0010
# Epoch 34/40
# 229/235 [============================>.] - ETA: 0s - loss: 0.0669
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 34: val_loss improved from 0.06722 to 0.06704, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 34: val_loss improved from 0.06722 to 0.06704, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 34: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 34: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 15s 62ms/step - loss: 0.0669 - val_loss: 0.0670 - lr: 0.0010
# Epoch 35/40
# 232/235 [============================>.] - ETA: 0s - loss: 0.0668
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 35: val_loss did not improve from 0.06704
#
# Epoch 35: val_loss did not improve from 0.06704
#
# Epoch 35: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 35: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 8s 36ms/step - loss: 0.0668 - val_loss: 0.0673 - lr: 0.0010
# Epoch 36/40
# 232/235 [============================>.] - ETA: 0s - loss: 0.0668
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 36: val_loss did not improve from 0.06704
#
# Epoch 36: val_loss did not improve from 0.06704
#
# Epoch 36: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 36: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 8s 33ms/step - loss: 0.0668 - val_loss: 0.0672 - lr: 0.0010
# Epoch 37/40
# 231/235 [============================>.] - ETA: 0s - loss: 0.0667
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 37: val_loss did not improve from 0.06704
#
# Epoch 37: val_loss did not improve from 0.06704
#
# Epoch 37: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 37: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 8s 34ms/step - loss: 0.0667 - val_loss: 0.0671 - lr: 0.0010
# Epoch 38/40
# 229/235 [============================>.] - ETA: 0s - loss: 0.0666
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 38: val_loss improved from 0.06704 to 0.06695, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 38: val_loss improved from 0.06704 to 0.06695, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 38: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 38: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 14s 60ms/step - loss: 0.0666 - val_loss: 0.0670 - lr: 0.0010
# Epoch 39/40
# 232/235 [============================>.] - ETA: 0s - loss: 0.0666
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 39: val_loss improved from 0.06695 to 0.06683, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 39: val_loss improved from 0.06695 to 0.06683, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 39: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 39: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 16s 67ms/step - loss: 0.0666 - val_loss: 0.0668 - lr: 0.0010
# Epoch 40/40
# 226/235 [===========================>..] - ETA: 0s - loss: 0.0666
# ***callbacks***
# saving losses to model/QAE_model8bits/callbacks\losses.log
#
# Epoch 40: val_loss improved from 0.06683 to 0.06677, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 40: val_loss improved from 0.06683 to 0.06677, saving model to model/QAE_model8bits/callbacks\KERAS_check_best_model_weights.h5
#
# Epoch 40: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 40: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_last_weights.h5
#
# Epoch 40: saving model to model/QAE_model8bits/callbacks\KERAS_check_model_epoch40.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 14s 60ms/step - loss: 0.0666 - val_loss: 0.0668 - lr: 0.0010
# 313/313 [==============================] - 1s 2ms/step
# 313/313 [==============================] - 2s 3ms/step
# 313/313 [==============================] - 1s 2ms/step

# %% [markdown]
# # Compressed QAE without classifier

# %%
network = QAutoencoder(data_zoom, pruned=True)
network.build_encoder()
network.build_decoder()
network.build_autoencoder()
network.fit_data(epochs=40)
network.plot_latent_dimension("Compressed QAE without classifier")
network.plot_reco(model_name=" compressed")
network.plot_score(use_latent_classifier=False,model_name="Compressed QAE without classifier")

# %% [markdown]
# # QAutoencoder with classifier

# %% [markdown]
# Repeating the same procedure for the autoencoder with classifier.

# %%
network_with_classifier = QAutoencoder(data_zoom, pruned=False)
network_with_classifier.build_encoder()
#network_with_classifier.build_decoder()
network_with_classifier.build_classifier()
network_with_classifier.build_autoencoder(use_latent_classifier=True)
network_with_classifier.fit_data( batch_size=256,epochs=40, use_latent_classifier=True)
network_with_classifier.plot_latent_dimension("QAutoencoder with classifier")
network_with_classifier.plot_score(use_latent_classifier=True,model_name="QAutoencoder with classifier")

# %% [markdown]
# ### Quantized only classifier

# %%
network_with_classifier = QAutoencoder(data_zoom, pruned=True)
network_with_classifier.build_encoder()
network_with_classifier.build_decoder()
network_with_classifier.build_classifier()
network_with_classifier.build_autoencoder(use_latent_classifier=True)
network_with_classifier.fit_data(epochs=40,use_latent_classifier=True)
network_with_classifier.plot_latent_dimension("Compressed QAE with classifier")
network_with_classifier.plot_score(use_latent_classifier=True,model_name="Compressed QAE with classifier")

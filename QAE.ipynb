# %%
from class_QAutoencoder import *

# %% [markdown]
# ### Import the MNIST data class and call it.

# %% [markdown]
# Original dataset and modified dataset with modifiable resolution is shown below.

# %%
# import MNIST_dataset as mnist
# size_final = 28

# data = mnist.MNISTData(size_initial=28, size_final=size_final, color_depth=8)
# train= data.x_train
# ax = plt.subplot(1, 1 , 1)

# plt.imshow(train[0].reshape(size_final,size_final), cmap='gray_r')
# ax.get_xaxis().set_visible(False)
# ax.get_yaxis().set_visible(False)

# %%
import MNIST_database as mnist

#Choose the final size of your image dataset
size_final = 8

data_zoom = mnist.MNISTData(size_initial=20, size_final=size_final, color_depth=5, flat=True)
train= data_zoom.x_train
ax = plt.subplot(1, 1 , 1)

plt.imshow(train[0].reshape(size_final,size_final), cmap='gray_r')
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)

# %% [markdown]
# # Autoencoder using Keras
# The aim of this class is to implement a simple autoencoder for the MNIST data and then build an autoencoder that is
# able to classify MNIST data in its latent dimension.
#
# Code partially adapted from [Keras Documentation](https://blog.keras.io/building-autoencoders-in-keras.html).

# %%
# file class_QAutoencoder.py

# %% [markdown]
# # QAutoencoder without classifier

# %% [markdown]
# It is built the standard autoencoder, *without classifier* here, and the MNIST data class called before is used.
# The model is fitted and adequate plots are reproduced,
# as well as the comparison between orginal MNIST dataset and reconstructed images.

# %%
network = QAutoencoder(data_zoom, pruned=False)
network.build_encoder()
network.build_decoder()
network.build_autoencoder()
network.fit_data(epochs=40)
network.plot_latent_dimension("QAutoencoder without classifier")
network.plot_reco(model_name=" complete")
network.plot_score(use_latent_classifier=False, model_name="Autoencoder without classifier")
network.plot_latent()
# Out:
# Model: "autoencoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  encoder_input (InputLayer)  [(None, 64)]              0
#
#  fc1 (QDense)                (None, 15)                975
#
#  relu1 (QActivation)         (None, 15)                0
#
#  fc2 (QDense)                (None, 15)                240
#
#  relu2 (QActivation)         (None, 15)                0
#
#  encoder_output (Dense)      (None, 2)                 32
#
#  fc3 (QDense)                (None, 16)                48
#
#  relu3_dec (QActivation)     (None, 16)                0
#
#  fc4 (QDense)                (None, 32)                544
#
#  relu4 (QActivation)         (None, 32)                0
#
#  fc5 (QDense)                (None, 32)                1056
#
#  relu5 (QActivation)         (None, 32)                0
#
#  decoder_output (QDense)     (None, 64)                2112
#
#  relu_decoder (QActivation)  (None, 64)                0
#
# =================================================================
# Total params: 5,007
# Trainable params: 5,007
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/40
# 234/235 [============================>.] - ETA: 0s - loss: 0.1171
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 1: val_loss improved from inf to 0.10883, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 1: val_loss improved from inf to 0.10883, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 1: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 1: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 17s 58ms/step - loss: 0.1171 - val_loss: 0.1088 - lr: 0.0010
# Epoch 2/40
# 226/235 [===========================>..] - ETA: 0s - loss: 0.1051
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 2: val_loss improved from 0.10883 to 0.10364, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 2: val_loss improved from 0.10883 to 0.10364, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 2: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 2: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 13s 55ms/step - loss: 0.1051 - val_loss: 0.1036 - lr: 0.0010
# Epoch 3/40
# 225/235 [===========================>..] - ETA: 0s - loss: 0.0998
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 3: val_loss improved from 0.10364 to 0.09554, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 3: val_loss improved from 0.10364 to 0.09554, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 3: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 3: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 11s 45ms/step - loss: 0.0996 - val_loss: 0.0955 - lr: 0.0010
# Epoch 4/40
# 224/235 [===========================>..] - ETA: 0s - loss: 0.0941
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 4: val_loss improved from 0.09554 to 0.09381, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 4: val_loss improved from 0.09554 to 0.09381, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 4: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 4: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 10s 43ms/step - loss: 0.0940 - val_loss: 0.0938 - lr: 0.0010
# Epoch 5/40
# 232/235 [============================>.] - ETA: 0s - loss: 0.0930
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 5: val_loss improved from 0.09381 to 0.09294, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 5: val_loss improved from 0.09381 to 0.09294, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 5: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 5: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 14s 59ms/step - loss: 0.0929 - val_loss: 0.0929 - lr: 0.0010
# Epoch 6/40
# 233/235 [============================>.] - ETA: 0s - loss: 0.0892
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 6: val_loss improved from 0.09294 to 0.08694, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 6: val_loss improved from 0.09294 to 0.08694, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 6: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 6: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 13s 54ms/step - loss: 0.0892 - val_loss: 0.0869 - lr: 0.0010
# Epoch 7/40
# 226/235 [===========================>..] - ETA: 0s - loss: 0.0838
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 7: val_loss improved from 0.08694 to 0.08216, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 7: val_loss improved from 0.08694 to 0.08216, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 7: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 7: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 14s 60ms/step - loss: 0.0836 - val_loss: 0.0822 - lr: 0.0010
# Epoch 8/40
# 230/235 [============================>.] - ETA: 0s - loss: 0.0807
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 8: val_loss improved from 0.08216 to 0.07952, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 8: val_loss improved from 0.08216 to 0.07952, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 8: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 8: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 12s 53ms/step - loss: 0.0806 - val_loss: 0.0795 - lr: 0.0010
# Epoch 9/40
# 226/235 [===========================>..] - ETA: 0s - loss: 0.0781
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 9: val_loss improved from 0.07952 to 0.07751, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 9: val_loss improved from 0.07952 to 0.07751, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 9: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 9: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 12s 52ms/step - loss: 0.0781 - val_loss: 0.0775 - lr: 0.0010
# Epoch 10/40
# 232/235 [============================>.] - ETA: 0s - loss: 0.0771
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 10: val_loss improved from 0.07751 to 0.07686, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 10: val_loss improved from 0.07751 to 0.07686, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 10: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 10: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# Epoch 10: saving model to model/QAE_model/model_2\KERAS_check_model_epoch10.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 12s 52ms/step - loss: 0.0771 - val_loss: 0.0769 - lr: 0.0010
# Epoch 11/40
# 229/235 [============================>.] - ETA: 0s - loss: 0.0763
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 11: val_loss improved from 0.07686 to 0.07614, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 11: val_loss improved from 0.07686 to 0.07614, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 11: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 11: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 13s 54ms/step - loss: 0.0763 - val_loss: 0.0761 - lr: 0.0010
# Epoch 12/40
# 232/235 [============================>.] - ETA: 0s - loss: 0.0756
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 12: val_loss improved from 0.07614 to 0.07464, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 12: val_loss improved from 0.07614 to 0.07464, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 12: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 12: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 13s 55ms/step - loss: 0.0756 - val_loss: 0.0746 - lr: 0.0010
# Epoch 13/40
# 224/235 [===========================>..] - ETA: 0s - loss: 0.0747
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 13: val_loss did not improve from 0.07464
#
# Epoch 13: val_loss did not improve from 0.07464
#
# Epoch 13: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 13: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 7s 31ms/step - loss: 0.0748 - val_loss: 0.0757 - lr: 0.0010
# Epoch 14/40
# 233/235 [============================>.] - ETA: 0s - loss: 0.0746
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 14: val_loss did not improve from 0.07464
#
# Epoch 14: val_loss did not improve from 0.07464
#
# Epoch 14: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 14: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 7s 31ms/step - loss: 0.0746 - val_loss: 0.0752 - lr: 0.0010
# Epoch 15/40
# 235/235 [==============================] - ETA: 0s - loss: 0.0738
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 15: val_loss improved from 0.07464 to 0.07426, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 15: val_loss improved from 0.07464 to 0.07426, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 15: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 15: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 12s 53ms/step - loss: 0.0738 - val_loss: 0.0743 - lr: 0.0010
# Epoch 16/40
# 232/235 [============================>.] - ETA: 0s - loss: 0.0732
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 16: val_loss improved from 0.07426 to 0.07342, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 16: val_loss improved from 0.07426 to 0.07342, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 16: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 16: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 12s 53ms/step - loss: 0.0732 - val_loss: 0.0734 - lr: 0.0010
# Epoch 17/40
# 234/235 [============================>.] - ETA: 0s - loss: 0.0729
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 17: val_loss improved from 0.07342 to 0.07266, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 17: val_loss improved from 0.07342 to 0.07266, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 17: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 17: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 12s 52ms/step - loss: 0.0729 - val_loss: 0.0727 - lr: 0.0010
# Epoch 18/40
# 234/235 [============================>.] - ETA: 0s - loss: 0.0723
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 18: val_loss improved from 0.07266 to 0.07254, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 18: val_loss improved from 0.07266 to 0.07254, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 18: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 18: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 12s 52ms/step - loss: 0.0723 - val_loss: 0.0725 - lr: 0.0010
# Epoch 19/40
# 232/235 [============================>.] - ETA: 0s - loss: 0.0720
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 19: val_loss did not improve from 0.07254
#
# Epoch 19: val_loss did not improve from 0.07254
#
# Epoch 19: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 19: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0720 - val_loss: 0.0729 - lr: 0.0010
# Epoch 20/40
# 233/235 [============================>.] - ETA: 0s - loss: 0.0717
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 20: val_loss improved from 0.07254 to 0.07194, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 20: val_loss improved from 0.07254 to 0.07194, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 20: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 20: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# Epoch 20: saving model to model/QAE_model/model_2\KERAS_check_model_epoch20.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 12s 51ms/step - loss: 0.0717 - val_loss: 0.0719 - lr: 0.0010
# Epoch 21/40
# 235/235 [==============================] - ETA: 0s - loss: 0.0716
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 21: val_loss improved from 0.07194 to 0.07157, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 21: val_loss improved from 0.07194 to 0.07157, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 21: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 21: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 12s 51ms/step - loss: 0.0716 - val_loss: 0.0716 - lr: 0.0010
# Epoch 22/40
# 235/235 [==============================] - ETA: 0s - loss: 0.0715
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 22: val_loss did not improve from 0.07157
#
# Epoch 22: val_loss did not improve from 0.07157
#
# Epoch 22: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 22: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 7s 31ms/step - loss: 0.0715 - val_loss: 0.0724 - lr: 0.0010
# Epoch 23/40
# 235/235 [==============================] - ETA: 0s - loss: 0.0715
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 23: val_loss improved from 0.07157 to 0.07137, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 23: val_loss improved from 0.07157 to 0.07137, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 23: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 23: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 12s 53ms/step - loss: 0.0715 - val_loss: 0.0714 - lr: 0.0010
# Epoch 24/40
# 233/235 [============================>.] - ETA: 0s - loss: 0.0712
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 24: val_loss did not improve from 0.07137
#
# Epoch 24: val_loss did not improve from 0.07137
#
# Epoch 24: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 24: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 6s 28ms/step - loss: 0.0712 - val_loss: 0.0720 - lr: 0.0010
# Epoch 25/40
# 228/235 [============================>.] - ETA: 0s - loss: 0.0709
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 25: val_loss did not improve from 0.07137
#
# Epoch 25: val_loss did not improve from 0.07137
#
# Epoch 25: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 25: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 7s 29ms/step - loss: 0.0709 - val_loss: 0.0714 - lr: 0.0010
# Epoch 26/40
# 222/235 [===========================>..] - ETA: 0s - loss: 0.0707
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 26: val_loss improved from 0.07137 to 0.07037, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 26: val_loss improved from 0.07137 to 0.07037, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 26: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 26: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 12s 51ms/step - loss: 0.0707 - val_loss: 0.0704 - lr: 0.0010
# Epoch 27/40
# 231/235 [============================>.] - ETA: 0s - loss: 0.0701
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 27: val_loss did not improve from 0.07037
#
# Epoch 27: val_loss did not improve from 0.07037
#
# Epoch 27: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 27: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 7s 29ms/step - loss: 0.0700 - val_loss: 0.0720 - lr: 0.0010
# Epoch 28/40
# 230/235 [============================>.] - ETA: 0s - loss: 0.0700
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 28: val_loss improved from 0.07037 to 0.06980, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 28: val_loss improved from 0.07037 to 0.06980, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 28: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 28: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 12s 52ms/step - loss: 0.0700 - val_loss: 0.0698 - lr: 0.0010
# Epoch 29/40
# 225/235 [===========================>..] - ETA: 0s - loss: 0.0698
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 29: val_loss did not improve from 0.06980
#
# Epoch 29: val_loss did not improve from 0.06980
#
# Epoch 29: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 29: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0698 - val_loss: 0.0698 - lr: 0.0010
# Epoch 30/40
# 228/235 [============================>.] - ETA: 0s - loss: 0.0698
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 30: val_loss improved from 0.06980 to 0.06976, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 30: val_loss improved from 0.06980 to 0.06976, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 30: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 30: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# Epoch 30: saving model to model/QAE_model/model_2\KERAS_check_model_epoch30.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 15s 63ms/step - loss: 0.0699 - val_loss: 0.0698 - lr: 0.0010
# Epoch 31/40
# 230/235 [============================>.] - ETA: 0s - loss: 0.0697
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 31: val_loss did not improve from 0.06976
#
# Epoch 31: val_loss did not improve from 0.06976
#
# Epoch 31: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 31: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 8s 33ms/step - loss: 0.0697 - val_loss: 0.0708 - lr: 0.0010
# Epoch 32/40
# 233/235 [============================>.] - ETA: 0s - loss: 0.0697
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 32: val_loss did not improve from 0.06976
#
# Epoch 32: val_loss did not improve from 0.06976
#
# Epoch 32: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 32: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 7s 31ms/step - loss: 0.0697 - val_loss: 0.0703 - lr: 0.0010
# Epoch 33/40
# 231/235 [============================>.] - ETA: 0s - loss: 0.0695
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 33: val_loss did not improve from 0.06976
#
# Epoch 33: val_loss did not improve from 0.06976
#
# Epoch 33: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 33: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 8s 32ms/step - loss: 0.0695 - val_loss: 0.0713 - lr: 0.0010
# Epoch 34/40
# 232/235 [============================>.] - ETA: 0s - loss: 0.0695
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 34: val_loss improved from 0.06976 to 0.06955, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 34: val_loss improved from 0.06976 to 0.06955, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 34: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 34: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 16s 70ms/step - loss: 0.0695 - val_loss: 0.0695 - lr: 0.0010
# Epoch 35/40
# 224/235 [===========================>..] - ETA: 0s - loss: 0.0692
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 35: val_loss did not improve from 0.06955
#
# Epoch 35: val_loss did not improve from 0.06955
#
# Epoch 35: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 35: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 6s 27ms/step - loss: 0.0692 - val_loss: 0.0706 - lr: 0.0010
# Epoch 36/40
# 228/235 [============================>.] - ETA: 0s - loss: 0.0677
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 36: val_loss improved from 0.06955 to 0.06766, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 36: val_loss improved from 0.06955 to 0.06766, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 36: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 36: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 13s 55ms/step - loss: 0.0677 - val_loss: 0.0677 - lr: 0.0010
# Epoch 37/40
# 235/235 [==============================] - ETA: 0s - loss: 0.0664
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 37: val_loss improved from 0.06766 to 0.06717, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 37: val_loss improved from 0.06766 to 0.06717, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 37: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 37: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 14s 59ms/step - loss: 0.0664 - val_loss: 0.0672 - lr: 0.0010
# Epoch 38/40
# 234/235 [============================>.] - ETA: 0s - loss: 0.0665
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 38: val_loss improved from 0.06717 to 0.06631, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 38: val_loss improved from 0.06717 to 0.06631, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 38: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 38: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 13s 56ms/step - loss: 0.0665 - val_loss: 0.0663 - lr: 0.0010
# Epoch 39/40
# 223/235 [===========================>..] - ETA: 0s - loss: 0.0665
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 39: val_loss did not improve from 0.06631
#
# Epoch 39: val_loss did not improve from 0.06631
#
# Epoch 39: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 39: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0665 - val_loss: 0.0667 - lr: 0.0010
# Epoch 40/40
# 229/235 [============================>.] - ETA: 0s - loss: 0.0662
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 40: val_loss did not improve from 0.06631
#
# Epoch 40: val_loss did not improve from 0.06631
#
# Epoch 40: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 40: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# Epoch 40: saving model to model/QAE_model/model_2\KERAS_check_model_epoch40.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 7s 31ms/step - loss: 0.0663 - val_loss: 0.0671 - lr: 0.0010
# 313/313 [==============================] - 1s 2ms/step
# 313/313 [==============================] - 2s 3ms/step
# 313/313 [==============================] - 1s 2ms/step

# %% [markdown]
# # Compressed QAE without classifier

# %%
network = QAutoencoder(data_zoom, pruned=True)
network.build_encoder()
network.build_decoder()
network.build_autoencoder()
network.fit_data(epochs=40)
network.plot_latent_dimension("Compressed QAE without classifier")
network.plot_reco(model_name=" compressed")
network.plot_score(use_latent_classifier=False,model_name="Compressed QAE without classifier")
# Out:
# Model: "autoencoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  encoder_input (InputLayer)  [(None, 64)]              0
#
#  fc1 (QDense)                (None, 15)                975
#
#  relu1 (QActivation)         (None, 15)                0
#
#  prune_low_magnitude_fc2_pru  (None, 15)               467
#  n (PruneLowMagnitude)
#
#  relu2 (QActivation)         (None, 15)                0
#
#  prune_low_magnitude_fc3_pru  (None, 15)               467
#  n (PruneLowMagnitude)
#
#  relu3_enc (QActivation)     (None, 15)                0
#
#  encoder_output (Dense)      (None, 2)                 32
#
#  prune_low_magnitude_fc3 (Pr  (None, 16)               82
#  uneLowMagnitude)
#
#  relu3_dec (QActivation)     (None, 16)                0
#
#  fc4 (QDense)                (None, 32)                544
#
#  relu4 (QActivation)         (None, 32)                0
#
#  fc5 (QDense)                (None, 32)                1056
#
#  relu5 (QActivation)         (None, 32)                0
#
#  decoder_output (QDense)     (None, 64)                2112
#
#  relu_decoder (QActivation)  (None, 64)                0
#
# =================================================================
# Total params: 5,735
# Trainable params: 5,247
# Non-trainable params: 488
# _________________________________________________________________
# Epoch 1/40
# 224/235 [===========================>..] - ETA: 0s - loss: 0.1152
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 1: val_loss improved from inf to 0.10114, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 1: val_loss improved from inf to 0.10114, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 1: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 1: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 26s 86ms/step - loss: 0.1146 - val_loss: 0.1011 - lr: 0.0010
# Epoch 2/40
# 227/235 [===========================>..] - ETA: 0s - loss: 0.1001
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 2: val_loss improved from 0.10114 to 0.09907, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 2: val_loss improved from 0.10114 to 0.09907, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 2: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 2: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 20s 84ms/step - loss: 0.1000 - val_loss: 0.0991 - lr: 0.0010
# Epoch 3/40
# 229/235 [============================>.] - ETA: 0s - loss: 0.0969
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 3: val_loss improved from 0.09907 to 0.09521, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 3: val_loss improved from 0.09907 to 0.09521, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 3: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 3: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 20s 87ms/step - loss: 0.0969 - val_loss: 0.0952 - lr: 0.0010
# Epoch 4/40
# 235/235 [==============================] - ETA: 0s - loss: 0.0935
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 4: val_loss improved from 0.09521 to 0.09313, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 4: val_loss improved from 0.09521 to 0.09313, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 4: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 4: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 25s 107ms/step - loss: 0.0935 - val_loss: 0.0931 - lr: 0.0010
# Epoch 5/40
# 233/235 [============================>.] - ETA: 0s - loss: 0.0917
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 5: val_loss improved from 0.09313 to 0.08903, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 5: val_loss improved from 0.09313 to 0.08903, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 5: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 5: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 19s 80ms/step - loss: 0.0917 - val_loss: 0.0890 - lr: 0.0010
# Epoch 6/40
# 229/235 [============================>.] - ETA: 0s - loss: 0.0890
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 6: val_loss improved from 0.08903 to 0.08824, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 6: val_loss improved from 0.08903 to 0.08824, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 6: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 6: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 18s 78ms/step - loss: 0.0890 - val_loss: 0.0882 - lr: 0.0010
# Epoch 7/40
# 229/235 [============================>.] - ETA: 0s - loss: 0.0883
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 7: val_loss improved from 0.08824 to 0.08631, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 7: val_loss improved from 0.08824 to 0.08631, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 7: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 7: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 19s 81ms/step - loss: 0.0883 - val_loss: 0.0863 - lr: 0.0010
# Epoch 8/40
# 226/235 [===========================>..] - ETA: 0s - loss: 0.0847
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 8: val_loss improved from 0.08631 to 0.08386, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 8: val_loss improved from 0.08631 to 0.08386, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 8: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 8: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 20s 83ms/step - loss: 0.0846 - val_loss: 0.0839 - lr: 0.0010
# Epoch 9/40
# 234/235 [============================>.] - ETA: 0s - loss: 0.0901
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 9: val_loss did not improve from 0.08386
#
# Epoch 9: val_loss did not improve from 0.08386
#
# Epoch 9: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 9: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 10s 44ms/step - loss: 0.0902 - val_loss: 0.0931 - lr: 0.0010
# Epoch 10/40
# 230/235 [============================>.] - ETA: 0s - loss: 0.0920
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 10: val_loss did not improve from 0.08386
#
# Epoch 10: val_loss did not improve from 0.08386
#
# Epoch 10: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 10: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# Epoch 10: saving model to model/QAE_model/model_2\KERAS_check_model_epoch10.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 11s 49ms/step - loss: 0.0919 - val_loss: 0.0906 - lr: 0.0010
# Epoch 11/40
# 233/235 [============================>.] - ETA: 0s - loss: 0.0902
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 11: val_loss did not improve from 0.08386
#
# Epoch 11: val_loss did not improve from 0.08386
#
# Epoch 11: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 11: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 11s 48ms/step - loss: 0.0902 - val_loss: 0.0898 - lr: 0.0010
# Epoch 12/40
# 230/235 [============================>.] - ETA: 0s - loss: 0.0886
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 12: val_loss did not improve from 0.08386
#
# Epoch 12: val_loss did not improve from 0.08386
#
# Epoch 12: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 12: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 12s 51ms/step - loss: 0.0886 - val_loss: 0.0873 - lr: 0.0010
# Epoch 13/40
# 235/235 [==============================] - ETA: 0s - loss: 0.0873
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 13: val_loss did not improve from 0.08386
#
# Epoch 13: val_loss did not improve from 0.08386
#
# Epoch 13: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 13: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 12s 50ms/step - loss: 0.0873 - val_loss: 0.0863 - lr: 0.0010
# Epoch 14/40
# 226/235 [===========================>..] - ETA: 0s - loss: 0.0867
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 14: val_loss did not improve from 0.08386
#
# Epoch 14: val_loss did not improve from 0.08386
#
# Epoch 14: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 14: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 11s 46ms/step - loss: 0.0867 - val_loss: 0.0856 - lr: 0.0010
# Epoch 15/40
# 234/235 [============================>.] - ETA: 0s - loss: 0.0860
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 15: val_loss did not improve from 0.08386
#
# Epoch 15: val_loss did not improve from 0.08386
#
# Epoch 15: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 15: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 10s 44ms/step - loss: 0.0860 - val_loss: 0.0858 - lr: 0.0010
# Epoch 16/40
# 234/235 [============================>.] - ETA: 0s - loss: 0.0855
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 16: val_loss did not improve from 0.08386
#
# Epoch 16: val_loss did not improve from 0.08386
#
# Epoch 16: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 16: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 12s 49ms/step - loss: 0.0855 - val_loss: 0.0845 - lr: 0.0010
# Epoch 17/40
# 227/235 [===========================>..] - ETA: 0s - loss: 0.0854
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 17: val_loss did not improve from 0.08386
#
# Epoch 17: val_loss did not improve from 0.08386
#
# Epoch 17: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 17: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 11s 46ms/step - loss: 0.0854 - val_loss: 0.0848 - lr: 0.0010
# Epoch 18/40
# 234/235 [============================>.] - ETA: 0s - loss: 0.0845
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 18: val_loss improved from 0.08386 to 0.08322, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 18: val_loss improved from 0.08386 to 0.08322, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 18: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 18: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 19s 81ms/step - loss: 0.0845 - val_loss: 0.0832 - lr: 0.0010
# Epoch 19/40
# 227/235 [===========================>..] - ETA: 0s - loss: 0.0848
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 19: val_loss did not improve from 0.08322
#
# Epoch 19: val_loss did not improve from 0.08322
#
# Epoch 19: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 19: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 12s 49ms/step - loss: 0.0847 - val_loss: 0.0846 - lr: 0.0010
# Epoch 20/40
# 226/235 [===========================>..] - ETA: 0s - loss: 0.0841
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 20: val_loss did not improve from 0.08322
#
# Epoch 20: val_loss did not improve from 0.08322
#
# Epoch 20: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 20: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# Epoch 20: saving model to model/QAE_model/model_2\KERAS_check_model_epoch20.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 11s 46ms/step - loss: 0.0841 - val_loss: 0.0836 - lr: 0.0010
# Epoch 21/40
# 230/235 [============================>.] - ETA: 0s - loss: 0.0835
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 21: val_loss improved from 0.08322 to 0.08207, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 21: val_loss improved from 0.08322 to 0.08207, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 21: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 21: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 20s 87ms/step - loss: 0.0835 - val_loss: 0.0821 - lr: 0.0010
# Epoch 22/40
# 233/235 [============================>.] - ETA: 0s - loss: 0.0828
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 22: val_loss improved from 0.08207 to 0.08110, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 22: val_loss improved from 0.08207 to 0.08110, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 22: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 22: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 16s 67ms/step - loss: 0.0828 - val_loss: 0.0811 - lr: 0.0010
# Epoch 23/40
# 234/235 [============================>.] - ETA: 0s - loss: 0.0817
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 23: val_loss did not improve from 0.08110
#
# Epoch 23: val_loss did not improve from 0.08110
#
# Epoch 23: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 23: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 10s 42ms/step - loss: 0.0817 - val_loss: 0.0825 - lr: 0.0010
# Epoch 24/40
# 228/235 [============================>.] - ETA: 0s - loss: 0.0815
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 24: val_loss did not improve from 0.08110
#
# Epoch 24: val_loss did not improve from 0.08110
#
# Epoch 24: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 24: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 12s 49ms/step - loss: 0.0815 - val_loss: 0.0814 - lr: 0.0010
# Epoch 25/40
# 234/235 [============================>.] - ETA: 0s - loss: 0.0810
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 25: val_loss improved from 0.08110 to 0.08036, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 25: val_loss improved from 0.08110 to 0.08036, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 25: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 25: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 20s 87ms/step - loss: 0.0810 - val_loss: 0.0804 - lr: 0.0010
# Epoch 26/40
# 234/235 [============================>.] - ETA: 0s - loss: 0.0810
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 26: val_loss improved from 0.08036 to 0.08003, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 26: val_loss improved from 0.08036 to 0.08003, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 26: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 26: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 22s 94ms/step - loss: 0.0810 - val_loss: 0.0800 - lr: 0.0010
# Epoch 27/40
# 233/235 [============================>.] - ETA: 0s - loss: 0.0810
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 27: val_loss did not improve from 0.08003
#
# Epoch 27: val_loss did not improve from 0.08003
#
# Epoch 27: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 27: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 11s 46ms/step - loss: 0.0810 - val_loss: 0.0819 - lr: 0.0010
# Epoch 28/40
# 230/235 [============================>.] - ETA: 0s - loss: 0.0808
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 28: val_loss improved from 0.08003 to 0.07961, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 28: val_loss improved from 0.08003 to 0.07961, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 28: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 28: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 19s 82ms/step - loss: 0.0808 - val_loss: 0.0796 - lr: 0.0010
# Epoch 29/40
# 229/235 [============================>.] - ETA: 0s - loss: 0.0808
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 29: val_loss did not improve from 0.07961
#
# Epoch 29: val_loss did not improve from 0.07961
#
# Epoch 29: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 29: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 11s 46ms/step - loss: 0.0807 - val_loss: 0.0803 - lr: 0.0010
# Epoch 30/40
# 229/235 [============================>.] - ETA: 0s - loss: 0.0804
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 30: val_loss did not improve from 0.07961
#
# Epoch 30: val_loss did not improve from 0.07961
#
# Epoch 30: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 30: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# Epoch 30: saving model to model/QAE_model/model_2\KERAS_check_model_epoch30.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 12s 50ms/step - loss: 0.0804 - val_loss: 0.0797 - lr: 0.0010
# Epoch 31/40
# 235/235 [==============================] - ETA: 0s - loss: 0.0801
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 31: val_loss did not improve from 0.07961
#
# Epoch 31: val_loss did not improve from 0.07961
#
# Epoch 31: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 31: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 18s 75ms/step - loss: 0.0801 - val_loss: 0.0811 - lr: 0.0010
# Epoch 32/40
# 229/235 [============================>.] - ETA: 0s - loss: 0.0801
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 32: val_loss did not improve from 0.07961
#
# Epoch 32: val_loss did not improve from 0.07961
#
# Epoch 32: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 32: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 17s 72ms/step - loss: 0.0801 - val_loss: 0.0804 - lr: 0.0010
# Epoch 33/40
# 229/235 [============================>.] - ETA: 0s - loss: 0.0799
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 33: val_loss did not improve from 0.07961
#
# Epoch 33: val_loss did not improve from 0.07961
#
# Epoch 33: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 33: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 13s 57ms/step - loss: 0.0799 - val_loss: 0.0797 - lr: 0.0010
# Epoch 34/40
# 234/235 [============================>.] - ETA: 0s - loss: 0.0799
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 34: val_loss improved from 0.07961 to 0.07936, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 34: val_loss improved from 0.07961 to 0.07936, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 34: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 34: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 22s 94ms/step - loss: 0.0799 - val_loss: 0.0794 - lr: 0.0010
# Epoch 35/40
# 229/235 [============================>.] - ETA: 0s - loss: 0.0799
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 35: val_loss did not improve from 0.07936
#
# Epoch 35: val_loss did not improve from 0.07936
#
# Epoch 35: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 35: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 11s 47ms/step - loss: 0.0799 - val_loss: 0.0797 - lr: 0.0010
# Epoch 36/40
# 232/235 [============================>.] - ETA: 0s - loss: 0.0798
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 36: val_loss did not improve from 0.07936
#
# Epoch 36: val_loss did not improve from 0.07936
#
# Epoch 36: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 36: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 12s 51ms/step - loss: 0.0798 - val_loss: 0.0797 - lr: 0.0010
# Epoch 37/40
# 235/235 [==============================] - ETA: 0s - loss: 0.0800
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 37: val_loss did not improve from 0.07936
#
# Epoch 37: val_loss did not improve from 0.07936
#
# Epoch 37: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 37: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 12s 53ms/step - loss: 0.0800 - val_loss: 0.0798 - lr: 0.0010
# Epoch 38/40
# 232/235 [============================>.] - ETA: 0s - loss: 0.0798
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 38: val_loss improved from 0.07936 to 0.07916, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 38: val_loss improved from 0.07936 to 0.07916, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 38: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 38: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 20s 87ms/step - loss: 0.0798 - val_loss: 0.0792 - lr: 0.0010
# Epoch 39/40
# 230/235 [============================>.] - ETA: 0s - loss: 0.0795
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 39: val_loss improved from 0.07916 to 0.07895, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 39: val_loss improved from 0.07916 to 0.07895, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 39: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 39: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 22s 95ms/step - loss: 0.0795 - val_loss: 0.0790 - lr: 0.0010
# Epoch 40/40
# 234/235 [============================>.] - ETA: 0s - loss: 0.0795
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 40: val_loss improved from 0.07895 to 0.07881, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 40: val_loss improved from 0.07895 to 0.07881, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 40: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 40: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# Epoch 40: saving model to model/QAE_model/model_2\KERAS_check_model_epoch40.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 28s 118ms/step - loss: 0.0795 - val_loss: 0.0788 - lr: 0.0010
# 313/313 [==============================] - 2s 2ms/step
# 313/313 [==============================] - 2s 3ms/step

# %% [markdown]
# # QAutoencoder with classifier

# %% [markdown]
# Repeating the same procedure for the autoencoder with classifier.

# %%
network_with_classifier = QAutoencoder(data_zoom, pruned=False)
network_with_classifier.build_encoder()
#network_with_classifier.build_decoder()
network_with_classifier.build_classifier()
network_with_classifier.build_autoencoder(use_latent_classifier=True)
network_with_classifier.fit_data( batch_size=256,epochs=40, use_latent_classifier=True)
network_with_classifier.plot_latent_dimension("QAutoencoder with classifier")
network_with_classifier.plot_score(use_latent_classifier=True,model_name="QAutoencoder with classifier")
# Out:
# Model: "classifier"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  encoder_input (InputLayer)  [(None, 64)]              0
#
#  fc1 (QDense)                (None, 15)                975
#
#  relu1 (QActivation)         (None, 15)                0
#
#  fc2 (QDense)                (None, 15)                240
#
#  relu2 (QActivation)         (None, 15)                0
#
#  encoder_output (Dense)      (None, 2)                 32
#
#  fc4_class (QDense)          (None, 16)                48
#
#  class_relu4 (QActivation)   (None, 16)                0
#
#  fc5_class (QDense)          (None, 40)                680
#
#  class_relu5 (QActivation)   (None, 40)                0
#
#  classifier_out (QDense)     (None, 10)                410
#
#  classifier_output (Activati  (None, 10)               0
#  on)
#
# =================================================================
# Total params: 2,385
# Trainable params: 2,385
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/40
# 233/235 [============================>.] - ETA: 0s - loss: 1.8665 - accuracy: 0.2956
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 1: val_loss improved from inf to 1.39868, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 1: val_loss improved from inf to 1.39868, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 1: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 1: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 21s 65ms/step - loss: 1.8641 - accuracy: 0.2966 - val_loss: 1.3987 - val_accuracy: 0.4744 - lr: 0.0010
# Epoch 2/40
# 231/235 [============================>.] - ETA: 0s - loss: 1.1989 - accuracy: 0.5638
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 2: val_loss improved from 1.39868 to 1.04124, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 2: val_loss improved from 1.39868 to 1.04124, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 2: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 2: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 14s 61ms/step - loss: 1.1968 - accuracy: 0.5648 - val_loss: 1.0412 - val_accuracy: 0.6406 - lr: 0.0010
# Epoch 3/40
# 225/235 [===========================>..] - ETA: 0s - loss: 0.9767 - accuracy: 0.6639
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 3: val_loss improved from 1.04124 to 0.90081, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 3: val_loss improved from 1.04124 to 0.90081, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 3: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 3: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 11s 47ms/step - loss: 0.9732 - accuracy: 0.6650 - val_loss: 0.9008 - val_accuracy: 0.6933 - lr: 0.0010
# Epoch 4/40
# 228/235 [============================>.] - ETA: 0s - loss: 0.8557 - accuracy: 0.7207
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 4: val_loss improved from 0.90081 to 0.77210, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 4: val_loss improved from 0.90081 to 0.77210, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 4: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 4: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 11s 45ms/step - loss: 0.8541 - accuracy: 0.7216 - val_loss: 0.7721 - val_accuracy: 0.7576 - lr: 0.0010
# Epoch 5/40
# 224/235 [===========================>..] - ETA: 0s - loss: 0.7458 - accuracy: 0.7574
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 5: val_loss improved from 0.77210 to 0.70656, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 5: val_loss improved from 0.77210 to 0.70656, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 5: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 5: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 10s 44ms/step - loss: 0.7457 - accuracy: 0.7577 - val_loss: 0.7066 - val_accuracy: 0.7812 - lr: 0.0010
# Epoch 6/40
# 222/235 [===========================>..] - ETA: 0s - loss: 0.6909 - accuracy: 0.7710
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 6: val_loss improved from 0.70656 to 0.66846, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 6: val_loss improved from 0.70656 to 0.66846, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 6: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 6: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 10s 44ms/step - loss: 0.6921 - accuracy: 0.7704 - val_loss: 0.6685 - val_accuracy: 0.7743 - lr: 0.0010
# Epoch 7/40
# 228/235 [============================>.] - ETA: 0s - loss: 0.6631 - accuracy: 0.7790
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 7: val_loss improved from 0.66846 to 0.64580, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 7: val_loss improved from 0.66846 to 0.64580, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 7: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 7: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 9s 37ms/step - loss: 0.6619 - accuracy: 0.7794 - val_loss: 0.6458 - val_accuracy: 0.7926 - lr: 0.0010
# Epoch 8/40
# 231/235 [============================>.] - ETA: 0s - loss: 0.6306 - accuracy: 0.7907
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 8: val_loss improved from 0.64580 to 0.61090, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 8: val_loss improved from 0.64580 to 0.61090, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 8: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 8: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 8s 36ms/step - loss: 0.6300 - accuracy: 0.7907 - val_loss: 0.6109 - val_accuracy: 0.7922 - lr: 0.0010
# Epoch 9/40
# 227/235 [===========================>..] - ETA: 0s - loss: 0.6169 - accuracy: 0.7943
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 9: val_loss did not improve from 0.61090
#
# Epoch 9: val_loss did not improve from 0.61090
#
# Epoch 9: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 9: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 5s 22ms/step - loss: 0.6163 - accuracy: 0.7942 - val_loss: 0.6126 - val_accuracy: 0.8054 - lr: 0.0010
# Epoch 10/40
# 224/235 [===========================>..] - ETA: 0s - loss: 0.6032 - accuracy: 0.8007
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 10: val_loss did not improve from 0.61090
#
# Epoch 10: val_loss did not improve from 0.61090
#
# Epoch 10: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 10: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# Epoch 10: saving model to model/QAE_model/model_2\KERAS_check_model_epoch10.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 6s 26ms/step - loss: 0.6027 - accuracy: 0.8007 - val_loss: 0.6123 - val_accuracy: 0.7852 - lr: 0.0010
# Epoch 11/40
# 234/235 [============================>.] - ETA: 0s - loss: 0.5922 - accuracy: 0.8038
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 11: val_loss improved from 0.61090 to 0.58985, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 11: val_loss improved from 0.61090 to 0.58985, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 11: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 11: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 10s 44ms/step - loss: 0.5921 - accuracy: 0.8038 - val_loss: 0.5899 - val_accuracy: 0.8118 - lr: 0.0010
# Epoch 12/40
# 225/235 [===========================>..] - ETA: 0s - loss: 0.5850 - accuracy: 0.8093
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 12: val_loss improved from 0.58985 to 0.56783, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 12: val_loss improved from 0.58985 to 0.56783, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 12: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 12: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 10s 43ms/step - loss: 0.5836 - accuracy: 0.8096 - val_loss: 0.5678 - val_accuracy: 0.8149 - lr: 0.0010
# Epoch 13/40
# 233/235 [============================>.] - ETA: 0s - loss: 0.5733 - accuracy: 0.8135
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 13: val_loss did not improve from 0.56783
#
# Epoch 13: val_loss did not improve from 0.56783
#
# Epoch 13: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 13: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 6s 25ms/step - loss: 0.5739 - accuracy: 0.8133 - val_loss: 0.5714 - val_accuracy: 0.8177 - lr: 0.0010
# Epoch 14/40
# 235/235 [==============================] - ETA: 0s - loss: 0.5609 - accuracy: 0.8225
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 14: val_loss improved from 0.56783 to 0.55137, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 14: val_loss improved from 0.56783 to 0.55137, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 14: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 14: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 11s 45ms/step - loss: 0.5609 - accuracy: 0.8225 - val_loss: 0.5514 - val_accuracy: 0.8331 - lr: 0.0010
# Epoch 15/40
# 232/235 [============================>.] - ETA: 0s - loss: 0.5536 - accuracy: 0.8301
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 15: val_loss improved from 0.55137 to 0.52606, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 15: val_loss improved from 0.55137 to 0.52606, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 15: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 15: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 12s 51ms/step - loss: 0.5535 - accuracy: 0.8301 - val_loss: 0.5261 - val_accuracy: 0.8421 - lr: 0.0010
# Epoch 16/40
# 233/235 [============================>.] - ETA: 0s - loss: 0.5380 - accuracy: 0.8407
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 16: val_loss improved from 0.52606 to 0.51885, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 16: val_loss improved from 0.52606 to 0.51885, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 16: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 16: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 11s 46ms/step - loss: 0.5379 - accuracy: 0.8408 - val_loss: 0.5188 - val_accuracy: 0.8516 - lr: 0.0010
# Epoch 17/40
# 228/235 [============================>.] - ETA: 0s - loss: 0.5255 - accuracy: 0.8475
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 17: val_loss improved from 0.51885 to 0.49804, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 17: val_loss improved from 0.51885 to 0.49804, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 17: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 17: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 11s 48ms/step - loss: 0.5259 - accuracy: 0.8474 - val_loss: 0.4980 - val_accuracy: 0.8579 - lr: 0.0010
# Epoch 18/40
# 227/235 [===========================>..] - ETA: 0s - loss: 0.5097 - accuracy: 0.8558
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 18: val_loss improved from 0.49804 to 0.49164, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 18: val_loss improved from 0.49804 to 0.49164, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 18: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 18: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 10s 43ms/step - loss: 0.5114 - accuracy: 0.8553 - val_loss: 0.4916 - val_accuracy: 0.8654 - lr: 0.0010
# Epoch 19/40
# 232/235 [============================>.] - ETA: 0s - loss: 0.5059 - accuracy: 0.8581
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 19: val_loss improved from 0.49164 to 0.47067, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 19: val_loss improved from 0.49164 to 0.47067, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 19: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 19: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 10s 44ms/step - loss: 0.5058 - accuracy: 0.8580 - val_loss: 0.4707 - val_accuracy: 0.8727 - lr: 0.0010
# Epoch 20/40
# 232/235 [============================>.] - ETA: 0s - loss: 0.4932 - accuracy: 0.8629
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 20: val_loss did not improve from 0.47067
#
# Epoch 20: val_loss did not improve from 0.47067
#
# Epoch 20: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 20: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# Epoch 20: saving model to model/QAE_model/model_2\KERAS_check_model_epoch20.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 5s 22ms/step - loss: 0.4938 - accuracy: 0.8628 - val_loss: 0.4778 - val_accuracy: 0.8674 - lr: 0.0010
# Epoch 21/40
# 220/235 [===========================>..] - ETA: 0s - loss: 0.4919 - accuracy: 0.8643
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 21: val_loss improved from 0.47067 to 0.46563, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 21: val_loss improved from 0.47067 to 0.46563, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 21: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 21: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 11s 48ms/step - loss: 0.4930 - accuracy: 0.8642 - val_loss: 0.4656 - val_accuracy: 0.8689 - lr: 0.0010
# Epoch 22/40
# 231/235 [============================>.] - ETA: 0s - loss: 0.4851 - accuracy: 0.8658
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 22: val_loss improved from 0.46563 to 0.45002, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 22: val_loss improved from 0.46563 to 0.45002, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 22: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 22: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 10s 42ms/step - loss: 0.4851 - accuracy: 0.8659 - val_loss: 0.4500 - val_accuracy: 0.8795 - lr: 0.0010
# Epoch 23/40
# 229/235 [============================>.] - ETA: 0s - loss: 0.4768 - accuracy: 0.8686
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 23: val_loss did not improve from 0.45002
#
# Epoch 23: val_loss did not improve from 0.45002
#
# Epoch 23: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 23: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 6s 27ms/step - loss: 0.4778 - accuracy: 0.8684 - val_loss: 0.4553 - val_accuracy: 0.8752 - lr: 0.0010
# Epoch 24/40
# 228/235 [============================>.] - ETA: 0s - loss: 0.4712 - accuracy: 0.8713
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 24: val_loss improved from 0.45002 to 0.44588, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 24: val_loss improved from 0.45002 to 0.44588, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 24: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 24: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 11s 45ms/step - loss: 0.4719 - accuracy: 0.8713 - val_loss: 0.4459 - val_accuracy: 0.8787 - lr: 0.0010
# Epoch 25/40
# 235/235 [==============================] - ETA: 0s - loss: 0.4663 - accuracy: 0.8736
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 25: val_loss improved from 0.44588 to 0.44161, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 25: val_loss improved from 0.44588 to 0.44161, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 25: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 25: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 10s 44ms/step - loss: 0.4663 - accuracy: 0.8736 - val_loss: 0.4416 - val_accuracy: 0.8821 - lr: 0.0010
# Epoch 26/40
# 224/235 [===========================>..] - ETA: 0s - loss: 0.4652 - accuracy: 0.8735
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 26: val_loss improved from 0.44161 to 0.42958, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 26: val_loss improved from 0.44161 to 0.42958, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 26: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 26: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 11s 46ms/step - loss: 0.4640 - accuracy: 0.8737 - val_loss: 0.4296 - val_accuracy: 0.8866 - lr: 0.0010
# Epoch 27/40
# 230/235 [============================>.] - ETA: 0s - loss: 0.4593 - accuracy: 0.8754
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 27: val_loss improved from 0.42958 to 0.42537, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 27: val_loss improved from 0.42958 to 0.42537, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 27: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 27: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 12s 50ms/step - loss: 0.4591 - accuracy: 0.8755 - val_loss: 0.4254 - val_accuracy: 0.8881 - lr: 0.0010
# Epoch 28/40
# 235/235 [==============================] - ETA: 0s - loss: 0.4526 - accuracy: 0.8785
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 28: val_loss did not improve from 0.42537
#
# Epoch 28: val_loss did not improve from 0.42537
#
# Epoch 28: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 28: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 6s 25ms/step - loss: 0.4526 - accuracy: 0.8785 - val_loss: 0.4333 - val_accuracy: 0.8835 - lr: 0.0010
# Epoch 29/40
# 227/235 [===========================>..] - ETA: 0s - loss: 0.4510 - accuracy: 0.8783
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 29: val_loss improved from 0.42537 to 0.41861, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 29: val_loss improved from 0.42537 to 0.41861, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 29: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 29: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 12s 52ms/step - loss: 0.4516 - accuracy: 0.8783 - val_loss: 0.4186 - val_accuracy: 0.8868 - lr: 0.0010
# Epoch 30/40
# 222/235 [===========================>..] - ETA: 0s - loss: 0.4466 - accuracy: 0.8789
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 30: val_loss improved from 0.41861 to 0.41781, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 30: val_loss improved from 0.41861 to 0.41781, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 30: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 30: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# Epoch 30: saving model to model/QAE_model/model_2\KERAS_check_model_epoch30.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 11s 46ms/step - loss: 0.4469 - accuracy: 0.8790 - val_loss: 0.4178 - val_accuracy: 0.8893 - lr: 0.0010
# Epoch 31/40
# 223/235 [===========================>..] - ETA: 0s - loss: 0.4376 - accuracy: 0.8819
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 31: val_loss did not improve from 0.41781
#
# Epoch 31: val_loss did not improve from 0.41781
#
# Epoch 31: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 31: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 6s 24ms/step - loss: 0.4399 - accuracy: 0.8814 - val_loss: 0.4244 - val_accuracy: 0.8876 - lr: 0.0010
# Epoch 32/40
# 228/235 [============================>.] - ETA: 0s - loss: 0.4385 - accuracy: 0.8823
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 32: val_loss did not improve from 0.41781
#
# Epoch 32: val_loss did not improve from 0.41781
#
# Epoch 32: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 32: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 6s 24ms/step - loss: 0.4379 - accuracy: 0.8827 - val_loss: 0.4224 - val_accuracy: 0.8876 - lr: 0.0010
# Epoch 33/40
# 222/235 [===========================>..] - ETA: 0s - loss: 0.4386 - accuracy: 0.8830
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 33: val_loss improved from 0.41781 to 0.40732, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 33: val_loss improved from 0.41781 to 0.40732, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 33: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 33: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 10s 44ms/step - loss: 0.4373 - accuracy: 0.8831 - val_loss: 0.4073 - val_accuracy: 0.8951 - lr: 0.0010
# Epoch 34/40
# 234/235 [============================>.] - ETA: 0s - loss: 0.4304 - accuracy: 0.8860
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 34: val_loss did not improve from 0.40732
#
# Epoch 34: val_loss did not improve from 0.40732
#
# Epoch 34: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 34: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 6s 28ms/step - loss: 0.4304 - accuracy: 0.8860 - val_loss: 0.4172 - val_accuracy: 0.8894 - lr: 0.0010
# Epoch 35/40
# 225/235 [===========================>..] - ETA: 0s - loss: 0.4291 - accuracy: 0.8864
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 35: val_loss improved from 0.40732 to 0.39374, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 35: val_loss improved from 0.40732 to 0.39374, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 35: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 35: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 14s 60ms/step - loss: 0.4290 - accuracy: 0.8864 - val_loss: 0.3937 - val_accuracy: 0.8972 - lr: 0.0010
# Epoch 36/40
# 231/235 [============================>.] - ETA: 0s - loss: 0.4309 - accuracy: 0.8854
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 36: val_loss did not improve from 0.39374
#
# Epoch 36: val_loss did not improve from 0.39374
#
# Epoch 36: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 36: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 6s 27ms/step - loss: 0.4306 - accuracy: 0.8855 - val_loss: 0.4071 - val_accuracy: 0.8922 - lr: 0.0010
# Epoch 37/40
# 229/235 [============================>.] - ETA: 0s - loss: 0.4256 - accuracy: 0.8874
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 37: val_loss did not improve from 0.39374
#
# Epoch 37: val_loss did not improve from 0.39374
#
# Epoch 37: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 37: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 6s 26ms/step - loss: 0.4260 - accuracy: 0.8872 - val_loss: 0.4073 - val_accuracy: 0.8923 - lr: 0.0010
# Epoch 38/40
# 225/235 [===========================>..] - ETA: 0s - loss: 0.4222 - accuracy: 0.8882
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 38: val_loss did not improve from 0.39374
#
# Epoch 38: val_loss did not improve from 0.39374
#
# Epoch 38: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 38: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 6s 25ms/step - loss: 0.4234 - accuracy: 0.8878 - val_loss: 0.4186 - val_accuracy: 0.8923 - lr: 0.0010
# Epoch 39/40
# 230/235 [============================>.] - ETA: 0s - loss: 0.4191 - accuracy: 0.8897
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 39: val_loss did not improve from 0.39374
#
# Epoch 39: val_loss did not improve from 0.39374
#
# Epoch 39: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 39: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 6s 25ms/step - loss: 0.4194 - accuracy: 0.8894 - val_loss: 0.3945 - val_accuracy: 0.8979 - lr: 0.0010
# Epoch 40/40
# 230/235 [============================>.] - ETA: 0s - loss: 0.4167 - accuracy: 0.8893
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 40: val_loss improved from 0.39374 to 0.39173, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 40: val_loss improved from 0.39374 to 0.39173, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 40: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 40: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# Epoch 40: saving model to model/QAE_model/model_2\KERAS_check_model_epoch40.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 10s 45ms/step - loss: 0.4156 - accuracy: 0.8898 - val_loss: 0.3917 - val_accuracy: 0.8989 - lr: 0.0010
# 313/313 [==============================] - 1s 2ms/step

# %% [markdown]
# ### Quantized only classifier

# %%
network_with_classifier = QAutoencoder(data_zoom, pruned=True)
network_with_classifier.build_encoder()
network_with_classifier.build_decoder()
network_with_classifier.build_classifier()
network_with_classifier.build_autoencoder(use_latent_classifier=True)
network_with_classifier.fit_data(epochs=40,use_latent_classifier=True)
network_with_classifier.plot_latent_dimension("Compressed QAE with classifier")
network_with_classifier.plot_score(use_latent_classifier=True,model_name="Compressed QAE with classifier")
# Out:
# Model: "classifier"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  encoder_input (InputLayer)  [(None, 64)]              0
#
#  fc1 (QDense)                (None, 15)                975
#
#  relu1 (QActivation)         (None, 15)                0
#
#  prune_low_magnitude_fc2_pru  (None, 15)               467
#  n (PruneLowMagnitude)
#
#  relu2 (QActivation)         (None, 15)                0
#
#  prune_low_magnitude_fc3_pru  (None, 15)               467
#  n (PruneLowMagnitude)
#
#  relu3_enc (QActivation)     (None, 15)                0
#
#  encoder_output (Dense)      (None, 2)                 32
#
#  prune_low_magnitude_fc4_pru  (None, 16)               82
#  nedclass (PruneLowMagnitude
#  )
#
#  prunclass_relu4 (QActivatio  (None, 16)               0
#  n)
#
#  fc5_class (QDense)          (None, 40)                680
#
#  class_relu5 (QActivation)   (None, 40)                0
#
#  classifier_out (QDense)     (None, 10)                410
#
#  classifier_output (Activati  (None, 10)               0
#  on)
#
# =================================================================
# Total params: 3,113
# Trainable params: 2,625
# Non-trainable params: 488
# _________________________________________________________________
# Epoch 1/40
# 234/235 [============================>.] - ETA: 0s - loss: 1.8748 - accuracy: 0.2932
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 1: val_loss improved from inf to 1.43872, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 1: val_loss improved from inf to 1.43872, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 1: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 1: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 22s 70ms/step - loss: 1.8741 - accuracy: 0.2932 - val_loss: 1.4387 - val_accuracy: 0.4007 - lr: 0.0010
# Epoch 2/40
# 224/235 [===========================>..] - ETA: 0s - loss: 1.3081 - accuracy: 0.4643
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 2: val_loss improved from 1.43872 to 1.18323, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 2: val_loss improved from 1.43872 to 1.18323, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 2: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 2: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 18s 77ms/step - loss: 1.3038 - accuracy: 0.4681 - val_loss: 1.1832 - val_accuracy: 0.5599 - lr: 0.0010
# Epoch 3/40
# 235/235 [==============================] - ETA: 0s - loss: 1.0653 - accuracy: 0.6368
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 3: val_loss improved from 1.18323 to 0.93869, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 3: val_loss improved from 1.18323 to 0.93869, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 3: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 3: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 21s 88ms/step - loss: 1.0653 - accuracy: 0.6368 - val_loss: 0.9387 - val_accuracy: 0.6909 - lr: 0.0010
# Epoch 4/40
# 235/235 [==============================] - ETA: 0s - loss: 0.8828 - accuracy: 0.7136
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 4: val_loss improved from 0.93869 to 0.80947, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 4: val_loss improved from 0.93869 to 0.80947, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 4: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 4: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 20s 86ms/step - loss: 0.8828 - accuracy: 0.7136 - val_loss: 0.8095 - val_accuracy: 0.7341 - lr: 0.0010
# Epoch 5/40
# 231/235 [============================>.] - ETA: 0s - loss: 0.7787 - accuracy: 0.7494
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 5: val_loss improved from 0.80947 to 0.72278, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 5: val_loss improved from 0.80947 to 0.72278, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 5: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 5: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 23s 98ms/step - loss: 0.7784 - accuracy: 0.7493 - val_loss: 0.7228 - val_accuracy: 0.7736 - lr: 0.0010
# Epoch 6/40
# 234/235 [============================>.] - ETA: 0s - loss: 0.7123 - accuracy: 0.7741
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 6: val_loss improved from 0.72278 to 0.66591, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 6: val_loss improved from 0.72278 to 0.66591, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 6: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 6: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 21s 88ms/step - loss: 0.7123 - accuracy: 0.7740 - val_loss: 0.6659 - val_accuracy: 0.7982 - lr: 0.0010
# Epoch 7/40
# 228/235 [============================>.] - ETA: 0s - loss: 0.6681 - accuracy: 0.7933
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 7: val_loss improved from 0.66591 to 0.63834, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 7: val_loss improved from 0.66591 to 0.63834, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 7: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 7: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 20s 87ms/step - loss: 0.6681 - accuracy: 0.7931 - val_loss: 0.6383 - val_accuracy: 0.8118 - lr: 0.0010
# Epoch 8/40
# 235/235 [==============================] - ETA: 0s - loss: 0.6314 - accuracy: 0.8122
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 8: val_loss improved from 0.63834 to 0.58945, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 8: val_loss improved from 0.63834 to 0.58945, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 8: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 8: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 20s 87ms/step - loss: 0.6314 - accuracy: 0.8122 - val_loss: 0.5894 - val_accuracy: 0.8390 - lr: 0.0010
# Epoch 9/40
# 226/235 [===========================>..] - ETA: 0s - loss: 1.1050 - accuracy: 0.6331
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 9: val_loss did not improve from 0.58945
#
# Epoch 9: val_loss did not improve from 0.58945
#
# Epoch 9: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 9: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 11s 47ms/step - loss: 1.1111 - accuracy: 0.6300 - val_loss: 1.2520 - val_accuracy: 0.5430 - lr: 0.0010
# Epoch 10/40
# 227/235 [===========================>..] - ETA: 0s - loss: 1.0992 - accuracy: 0.6130
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 10: val_loss did not improve from 0.58945
#
# Epoch 10: val_loss did not improve from 0.58945
#
# Epoch 10: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 10: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# Epoch 10: saving model to model/QAE_model/model_2\KERAS_check_model_epoch10.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 11s 48ms/step - loss: 1.0961 - accuracy: 0.6153 - val_loss: 0.9950 - val_accuracy: 0.6277 - lr: 0.0010
# Epoch 11/40
# 225/235 [===========================>..] - ETA: 0s - loss: 0.9212 - accuracy: 0.7335
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 11: val_loss did not improve from 0.58945
#
# Epoch 11: val_loss did not improve from 0.58945
#
# Epoch 11: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 11: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 11s 45ms/step - loss: 0.9190 - accuracy: 0.7348 - val_loss: 0.8564 - val_accuracy: 0.7744 - lr: 0.0010
# Epoch 12/40
# 230/235 [============================>.] - ETA: 0s - loss: 0.8311 - accuracy: 0.7747
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 12: val_loss did not improve from 0.58945
#
# Epoch 12: val_loss did not improve from 0.58945
#
# Epoch 12: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 12: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 11s 46ms/step - loss: 0.8317 - accuracy: 0.7743 - val_loss: 0.7772 - val_accuracy: 0.7925 - lr: 0.0010
# Epoch 13/40
# 234/235 [============================>.] - ETA: 0s - loss: 0.7699 - accuracy: 0.7910
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 13: val_loss did not improve from 0.58945
#
# Epoch 13: val_loss did not improve from 0.58945
#
# Epoch 13: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 13: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 10s 43ms/step - loss: 0.7698 - accuracy: 0.7911 - val_loss: 0.7165 - val_accuracy: 0.8100 - lr: 0.0010
# Epoch 14/40
# 231/235 [============================>.] - ETA: 0s - loss: 0.7263 - accuracy: 0.8012
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 14: val_loss did not improve from 0.58945
#
# Epoch 14: val_loss did not improve from 0.58945
#
# Epoch 14: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 14: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 11s 45ms/step - loss: 0.7260 - accuracy: 0.8013 - val_loss: 0.6919 - val_accuracy: 0.8195 - lr: 0.0010
# Epoch 15/40
# 234/235 [============================>.] - ETA: 0s - loss: 0.7003 - accuracy: 0.8103
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 15: val_loss did not improve from 0.58945
#
# Epoch 15: val_loss did not improve from 0.58945
#
# Epoch 15: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 15: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 9s 41ms/step - loss: 0.7002 - accuracy: 0.8104 - val_loss: 0.6944 - val_accuracy: 0.8147 - lr: 0.0010
# Epoch 16/40
# 222/235 [===========================>..] - ETA: 0s - loss: 0.6755 - accuracy: 0.8161
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 16: val_loss did not improve from 0.58945
#
# Epoch 16: val_loss did not improve from 0.58945
#
# Epoch 16: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 16: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 10s 42ms/step - loss: 0.6753 - accuracy: 0.8161 - val_loss: 0.6404 - val_accuracy: 0.8333 - lr: 0.0010
# Epoch 17/40
# 230/235 [============================>.] - ETA: 0s - loss: 0.6507 - accuracy: 0.8226
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 17: val_loss did not improve from 0.58945
#
# Epoch 17: val_loss did not improve from 0.58945
#
# Epoch 17: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 17: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 10s 42ms/step - loss: 0.6508 - accuracy: 0.8227 - val_loss: 0.6206 - val_accuracy: 0.8350 - lr: 0.0010
# Epoch 18/40
# 226/235 [===========================>..] - ETA: 0s - loss: 0.6379 - accuracy: 0.8263
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 18: val_loss did not improve from 0.58945
#
# Epoch 18: val_loss did not improve from 0.58945
#
# Epoch 18: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 18: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# ***callbacks end***
#
# 235/235 [==============================] - 9s 40ms/step - loss: 0.6378 - accuracy: 0.8262 - val_loss: 0.6126 - val_accuracy: 0.8377 - lr: 0.0010
# Epoch 19/40
# 224/235 [===========================>..] - ETA: 0s - loss: 0.6225 - accuracy: 0.8320
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 19: val_loss did not improve from 0.58945
#
# Epoch 19: val_loss did not improve from 0.58945
#
# Epoch 19: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 19: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 10s 43ms/step - loss: 0.6204 - accuracy: 0.8323 - val_loss: 0.6033 - val_accuracy: 0.8444 - lr: 5.0000e-04
# Epoch 20/40
# 224/235 [===========================>..] - ETA: 0s - loss: 0.6077 - accuracy: 0.8348
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 20: val_loss did not improve from 0.58945
#
# Epoch 20: val_loss did not improve from 0.58945
#
# Epoch 20: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 20: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# Epoch 20: saving model to model/QAE_model/model_2\KERAS_check_model_epoch20.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 12s 51ms/step - loss: 0.6096 - accuracy: 0.8345 - val_loss: 0.5969 - val_accuracy: 0.8403 - lr: 5.0000e-04
# Epoch 21/40
# 233/235 [============================>.] - ETA: 0s - loss: 0.6063 - accuracy: 0.8354
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 21: val_loss did not improve from 0.58945
#
# Epoch 21: val_loss did not improve from 0.58945
#
# Epoch 21: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 21: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 13s 53ms/step - loss: 0.6066 - accuracy: 0.8353 - val_loss: 0.5910 - val_accuracy: 0.8404 - lr: 5.0000e-04
# Epoch 22/40
# 232/235 [============================>.] - ETA: 0s - loss: 0.6014 - accuracy: 0.8372
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 22: val_loss did not improve from 0.58945
#
# Epoch 22: val_loss did not improve from 0.58945
#
# Epoch 22: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 22: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 18s 76ms/step - loss: 0.6018 - accuracy: 0.8371 - val_loss: 0.5987 - val_accuracy: 0.8406 - lr: 5.0000e-04
# Epoch 23/40
# 231/235 [============================>.] - ETA: 0s - loss: 0.6026 - accuracy: 0.8360
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 23: val_loss improved from 0.58945 to 0.58077, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 23: val_loss improved from 0.58945 to 0.58077, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 23: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 23: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 26s 110ms/step - loss: 0.6022 - accuracy: 0.8361 - val_loss: 0.5808 - val_accuracy: 0.8455 - lr: 5.0000e-04
# Epoch 24/40
# 232/235 [============================>.] - ETA: 0s - loss: 0.6030 - accuracy: 0.8334
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 24: val_loss improved from 0.58077 to 0.57915, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 24: val_loss improved from 0.58077 to 0.57915, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 24: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 24: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 21s 89ms/step - loss: 0.6024 - accuracy: 0.8335 - val_loss: 0.5792 - val_accuracy: 0.8434 - lr: 5.0000e-04
# Epoch 25/40
# 225/235 [===========================>..] - ETA: 0s - loss: 0.5953 - accuracy: 0.8365
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 25: val_loss did not improve from 0.57915
#
# Epoch 25: val_loss did not improve from 0.57915
#
# Epoch 25: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 25: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 11s 46ms/step - loss: 0.5960 - accuracy: 0.8361 - val_loss: 0.6084 - val_accuracy: 0.8350 - lr: 5.0000e-04
# Epoch 26/40
# 228/235 [============================>.] - ETA: 0s - loss: 0.5883 - accuracy: 0.8396
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 26: val_loss improved from 0.57915 to 0.57231, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 26: val_loss improved from 0.57915 to 0.57231, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 26: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 26: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 21s 91ms/step - loss: 0.5876 - accuracy: 0.8399 - val_loss: 0.5723 - val_accuracy: 0.8476 - lr: 5.0000e-04
# Epoch 27/40
# 235/235 [==============================] - ETA: 0s - loss: 0.5829 - accuracy: 0.8408
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 27: val_loss improved from 0.57231 to 0.56639, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 27: val_loss improved from 0.57231 to 0.56639, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 27: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 27: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 34s 143ms/step - loss: 0.5829 - accuracy: 0.8408 - val_loss: 0.5664 - val_accuracy: 0.8477 - lr: 5.0000e-04
# Epoch 28/40
# 233/235 [============================>.] - ETA: 0s - loss: 0.5808 - accuracy: 0.8407
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 28: val_loss improved from 0.56639 to 0.56466, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 28: val_loss improved from 0.56639 to 0.56466, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 28: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 28: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 44s 187ms/step - loss: 0.5809 - accuracy: 0.8406 - val_loss: 0.5647 - val_accuracy: 0.8475 - lr: 5.0000e-04
# Epoch 29/40
# 227/235 [===========================>..] - ETA: 0s - loss: 0.5811 - accuracy: 0.8411
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 29: val_loss improved from 0.56466 to 0.55715, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 29: val_loss improved from 0.56466 to 0.55715, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 29: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 29: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 46s 194ms/step - loss: 0.5810 - accuracy: 0.8412 - val_loss: 0.5571 - val_accuracy: 0.8504 - lr: 5.0000e-04
# Epoch 30/40
# 229/235 [============================>.] - ETA: 0s - loss: 0.5748 - accuracy: 0.8423
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 30: val_loss improved from 0.55715 to 0.55704, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 30: val_loss improved from 0.55715 to 0.55704, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 30: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 30: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# Epoch 30: saving model to model/QAE_model/model_2\KERAS_check_model_epoch30.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 48s 204ms/step - loss: 0.5743 - accuracy: 0.8425 - val_loss: 0.5570 - val_accuracy: 0.8489 - lr: 5.0000e-04
# Epoch 31/40
# 235/235 [==============================] - ETA: 0s - loss: 0.5760 - accuracy: 0.8424
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 31: val_loss did not improve from 0.55704
#
# Epoch 31: val_loss did not improve from 0.55704
#
# Epoch 31: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 31: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 38s 160ms/step - loss: 0.5760 - accuracy: 0.8424 - val_loss: 0.5916 - val_accuracy: 0.8427 - lr: 5.0000e-04
# Epoch 32/40
# 228/235 [============================>.] - ETA: 0s - loss: 0.5752 - accuracy: 0.8438
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 32: val_loss did not improve from 0.55704
#
# Epoch 32: val_loss did not improve from 0.55704
#
# Epoch 32: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 32: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 31s 132ms/step - loss: 0.5759 - accuracy: 0.8437 - val_loss: 0.5660 - val_accuracy: 0.8473 - lr: 5.0000e-04
# Epoch 33/40
# 234/235 [============================>.] - ETA: 0s - loss: 0.5718 - accuracy: 0.8435
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 33: val_loss did not improve from 0.55704
#
# Epoch 33: val_loss did not improve from 0.55704
#
# Epoch 33: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 33: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 12s 50ms/step - loss: 0.5719 - accuracy: 0.8435 - val_loss: 0.5698 - val_accuracy: 0.8478 - lr: 5.0000e-04
# Epoch 34/40
# 232/235 [============================>.] - ETA: 0s - loss: 0.5696 - accuracy: 0.8431
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 34: val_loss improved from 0.55704 to 0.54727, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 34: val_loss improved from 0.55704 to 0.54727, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 34: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 34: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 20s 83ms/step - loss: 0.5696 - accuracy: 0.8431 - val_loss: 0.5473 - val_accuracy: 0.8517 - lr: 5.0000e-04
# Epoch 35/40
# 233/235 [============================>.] - ETA: 0s - loss: 0.5691 - accuracy: 0.8441
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 35: val_loss did not improve from 0.54727
#
# Epoch 35: val_loss did not improve from 0.54727
#
# Epoch 35: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 35: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 9s 40ms/step - loss: 0.5691 - accuracy: 0.8441 - val_loss: 0.5533 - val_accuracy: 0.8507 - lr: 5.0000e-04
# Epoch 36/40
# 228/235 [============================>.] - ETA: 0s - loss: 0.5663 - accuracy: 0.8449
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 36: val_loss improved from 0.54727 to 0.54047, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 36: val_loss improved from 0.54727 to 0.54047, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 36: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 36: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 26s 110ms/step - loss: 0.5661 - accuracy: 0.8449 - val_loss: 0.5405 - val_accuracy: 0.8559 - lr: 5.0000e-04
# Epoch 37/40
# 232/235 [============================>.] - ETA: 0s - loss: 0.5609 - accuracy: 0.8458
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 37: val_loss improved from 0.54047 to 0.53372, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 37: val_loss improved from 0.54047 to 0.53372, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 37: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 37: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 24s 102ms/step - loss: 0.5609 - accuracy: 0.8458 - val_loss: 0.5337 - val_accuracy: 0.8580 - lr: 5.0000e-04
# Epoch 38/40
# 226/235 [===========================>..] - ETA: 0s - loss: 0.5634 - accuracy: 0.8457
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 38: val_loss did not improve from 0.53372
#
# Epoch 38: val_loss did not improve from 0.53372
#
# Epoch 38: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 38: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 10s 45ms/step - loss: 0.5633 - accuracy: 0.8457 - val_loss: 0.5860 - val_accuracy: 0.8359 - lr: 5.0000e-04
# Epoch 39/40
# 226/235 [===========================>..] - ETA: 0s - loss: 0.5601 - accuracy: 0.8456
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 39: val_loss did not improve from 0.53372
#
# Epoch 39: val_loss did not improve from 0.53372
#
# Epoch 39: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 39: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 11s 45ms/step - loss: 0.5600 - accuracy: 0.8454 - val_loss: 0.5615 - val_accuracy: 0.8466 - lr: 5.0000e-04
# Epoch 40/40
# 235/235 [==============================] - ETA: 0s - loss: 0.5508 - accuracy: 0.8502
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 40: val_loss improved from 0.53372 to 0.52867, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 40: val_loss improved from 0.53372 to 0.52867, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 40: saving model to model/QAE_model/model_2\KERAS_check_model_last.model
# WARNING:absl:Found untraced functions such as _update_step_xla, fc2_prun_layer_call_fn, fc2_prun_layer_call_and_return_conditional_losses, fc3_prun_layer_call_fn, fc3_prun_layer_call_and_return_conditional_losses while saving (showing 5 of 7). These functions will not be directly callable after loading.
# Epoch 40: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# Epoch 40: saving model to model/QAE_model/model_2\KERAS_check_model_epoch40.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 19s 83ms/step - loss: 0.5508 - accuracy: 0.8502 - val_loss: 0.5287 - val_accuracy: 0.8564 - lr: 5.0000e-04
# 313/313 [==============================] - 1s 3ms/step

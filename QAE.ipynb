# %%
from class_QAutoencoder import *

# %% [markdown]
# ### Import the MNIST data class and call it.

# %% [markdown]
# Original dataset and modified dataset with modifiable resolution is shown below.

# %%
# import MNIST_dataset as mnist
# size_final = 28

# data = mnist.MNISTData(size_initial=28, size_final=size_final, color_depth=8)
# train= data.x_train
# ax = plt.subplot(1, 1 , 1)

# plt.imshow(train[0].reshape(size_final,size_final), cmap='gray_r')
# ax.get_xaxis().set_visible(False)
# ax.get_yaxis().set_visible(False)

# %%
import MNIST_database as mnist

#Choose the final size of your image dataset
size_final = 8

data_zoom = mnist.MNISTData(size_initial=20, size_final=size_final, color_depth=5, flat=True)
train= data_zoom.x_train
ax = plt.subplot(1, 1 , 1)

plt.imshow(train[0].reshape(size_final,size_final), cmap='gray_r')
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)

# %% [markdown]
# # Autoencoder using Keras
# The aim of this class is to implement a simple autoencoder for the MNIST data and then build an autoencoder that is
# able to classify MNIST data in its latent dimension.
#
# Code partially adapted from [Keras Documentation](https://blog.keras.io/building-autoencoders-in-keras.html).

# %%
# file class_QAutoencoder.py

# %% [markdown]
# It is built the standard autoencoder, *without classifier* here, and the MNIST data class called before is used.
# The model is fitted and adequate plots are reproduced,
# as well as the comparison between orginal MNIST dataset and reconstructed images.

# %%
network = QAutoencoder(data_zoom, pruned=False)
network.build_encoder()
network.build_decoder()
network.build_autoencoder()
network.fit_data(epochs=40)
network.plot_latent_dimension("QAutoencoder without classifier")
network.plot_reco(model_name=" complete")
network.plot_score(use_latent_classifier=False, model_name="Autoencoder without classifier")
network.plot_latent()
# Out:
# Model: "autoencoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  encoder_input (InputLayer)  [(None, 64)]              0
#
#  fc1 (QDense)                (None, 15)                975
#
#  relu1 (QActivation)         (None, 15)                0
#
#  fc2 (QDense)                (None, 15)                240
#
#  relu2 (QActivation)         (None, 15)                0
#
#  encoder_output (Dense)      (None, 2)                 32
#
#  fc3 (QDense)                (None, 16)                48
#
#  relu3 (QActivation)         (None, 16)                0
#
#  fc4 (QDense)                (None, 32)                544
#
#  relu4 (QActivation)         (None, 32)                0
#
#  fc5 (QDense)                (None, 32)                1056
#
#  relu5 (QActivation)         (None, 32)                0
#
#  decoder_output (QDense)     (None, 64)                2112
#
#  relu_decoder (QActivation)  (None, 64)                0
#
# =================================================================
# Total params: 5,007
# Trainable params: 5,007
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/40
# 230/235 [============================>.] - ETA: 0s - loss: 0.1061
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 1: val_loss improved from inf to 0.09191, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 1: val_loss improved from inf to 0.09191, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 1: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 1: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 10s 29ms/step - loss: 0.1059 - val_loss: 0.0919 - lr: 0.0010
# Epoch 2/40
# 234/235 [============================>.] - ETA: 0s - loss: 0.0893
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 2: val_loss improved from 0.09191 to 0.08673, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 2: val_loss improved from 0.09191 to 0.08673, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 2: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 2: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 7s 31ms/step - loss: 0.0893 - val_loss: 0.0867 - lr: 0.0010
# Epoch 3/40
# 234/235 [============================>.] - ETA: 0s - loss: 0.0854
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 3: val_loss improved from 0.08673 to 0.08395, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 3: val_loss improved from 0.08673 to 0.08395, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 3: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 3: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 7s 31ms/step - loss: 0.0854 - val_loss: 0.0839 - lr: 0.0010
# Epoch 4/40
# 232/235 [============================>.] - ETA: 0s - loss: 0.0809
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 4: val_loss improved from 0.08395 to 0.07931, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 4: val_loss improved from 0.08395 to 0.07931, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 4: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 4: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0809 - val_loss: 0.0793 - lr: 0.0010
# Epoch 5/40
# 231/235 [============================>.] - ETA: 0s - loss: 0.0787
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 5: val_loss improved from 0.07931 to 0.07780, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 5: val_loss improved from 0.07931 to 0.07780, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 5: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 5: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 7s 29ms/step - loss: 0.0787 - val_loss: 0.0778 - lr: 0.0010
# Epoch 6/40
# 229/235 [============================>.] - ETA: 0s - loss: 0.0772
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 6: val_loss improved from 0.07780 to 0.07638, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 6: val_loss improved from 0.07780 to 0.07638, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 6: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 6: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 7s 31ms/step - loss: 0.0772 - val_loss: 0.0764 - lr: 0.0010
# Epoch 7/40
# 227/235 [===========================>..] - ETA: 0s - loss: 0.0757
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 7: val_loss improved from 0.07638 to 0.07487, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 7: val_loss improved from 0.07638 to 0.07487, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 7: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 7: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 7s 31ms/step - loss: 0.0757 - val_loss: 0.0749 - lr: 0.0010
# Epoch 8/40
# 228/235 [============================>.] - ETA: 0s - loss: 0.0746
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 8: val_loss improved from 0.07487 to 0.07405, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 8: val_loss improved from 0.07487 to 0.07405, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 8: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 8: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 7s 29ms/step - loss: 0.0746 - val_loss: 0.0741 - lr: 0.0010
# Epoch 9/40
# 229/235 [============================>.] - ETA: 0s - loss: 0.0731
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 9: val_loss improved from 0.07405 to 0.07294, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 9: val_loss improved from 0.07405 to 0.07294, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 9: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 9: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 7s 32ms/step - loss: 0.0731 - val_loss: 0.0729 - lr: 0.0010
# Epoch 10/40
# 233/235 [============================>.] - ETA: 0s - loss: 0.0722
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 10: val_loss improved from 0.07294 to 0.07176, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 10: val_loss improved from 0.07294 to 0.07176, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 10: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 10: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# Epoch 10: saving model to model/QAE_model/model_2\KERAS_check_model_epoch10.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 10s 41ms/step - loss: 0.0723 - val_loss: 0.0718 - lr: 0.0010
# Epoch 11/40
# 229/235 [============================>.] - ETA: 0s - loss: 0.0717
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 11: val_loss improved from 0.07176 to 0.07115, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 11: val_loss improved from 0.07176 to 0.07115, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 11: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 11: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 8s 35ms/step - loss: 0.0716 - val_loss: 0.0711 - lr: 0.0010
# Epoch 12/40
# 230/235 [============================>.] - ETA: 0s - loss: 0.0708
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 12: val_loss improved from 0.07115 to 0.07078, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 12: val_loss improved from 0.07115 to 0.07078, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 12: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 12: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 9s 38ms/step - loss: 0.0709 - val_loss: 0.0708 - lr: 0.0010
# Epoch 13/40
# 232/235 [============================>.] - ETA: 0s - loss: 0.0705
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 13: val_loss improved from 0.07078 to 0.06999, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 13: val_loss improved from 0.07078 to 0.06999, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 13: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 13: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 9s 37ms/step - loss: 0.0705 - val_loss: 0.0700 - lr: 0.0010
# Epoch 14/40
# 231/235 [============================>.] - ETA: 0s - loss: 0.0700
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 14: val_loss improved from 0.06999 to 0.06961, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 14: val_loss improved from 0.06999 to 0.06961, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 14: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 14: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 8s 35ms/step - loss: 0.0700 - val_loss: 0.0696 - lr: 0.0010
# Epoch 15/40
# 231/235 [============================>.] - ETA: 0s - loss: 0.0697
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 15: val_loss improved from 0.06961 to 0.06939, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 15: val_loss improved from 0.06961 to 0.06939, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 15: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 15: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 8s 35ms/step - loss: 0.0697 - val_loss: 0.0694 - lr: 0.0010
# Epoch 16/40
# 231/235 [============================>.] - ETA: 0s - loss: 0.0696
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 16: val_loss improved from 0.06939 to 0.06936, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 16: val_loss improved from 0.06939 to 0.06936, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 16: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 16: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 8s 34ms/step - loss: 0.0696 - val_loss: 0.0694 - lr: 0.0010
# Epoch 17/40
# 230/235 [============================>.] - ETA: 0s - loss: 0.0694
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 17: val_loss improved from 0.06936 to 0.06873, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 17: val_loss improved from 0.06936 to 0.06873, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 17: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 17: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0694 - val_loss: 0.0687 - lr: 0.0010
# Epoch 18/40
# 234/235 [============================>.] - ETA: 0s - loss: 0.0690
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 18: val_loss did not improve from 0.06873
#
# Epoch 18: val_loss did not improve from 0.06873
#
# Epoch 18: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 18: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0690 - val_loss: 0.0691 - lr: 0.0010
# Epoch 19/40
# 234/235 [============================>.] - ETA: 0s - loss: 0.0689
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 19: val_loss improved from 0.06873 to 0.06830, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 19: val_loss improved from 0.06873 to 0.06830, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 19: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 19: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 7s 31ms/step - loss: 0.0689 - val_loss: 0.0683 - lr: 0.0010
# Epoch 20/40
# 231/235 [============================>.] - ETA: 0s - loss: 0.0688
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 20: val_loss improved from 0.06830 to 0.06823, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 20: val_loss improved from 0.06830 to 0.06823, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 20: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 20: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# Epoch 20: saving model to model/QAE_model/model_2\KERAS_check_model_epoch20.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 8s 34ms/step - loss: 0.0688 - val_loss: 0.0682 - lr: 0.0010
# Epoch 21/40
# 229/235 [============================>.] - ETA: 0s - loss: 0.0686
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 21: val_loss improved from 0.06823 to 0.06792, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 21: val_loss improved from 0.06823 to 0.06792, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 21: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 21: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 10s 43ms/step - loss: 0.0686 - val_loss: 0.0679 - lr: 0.0010
# Epoch 22/40
# 230/235 [============================>.] - ETA: 0s - loss: 0.0684
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 22: val_loss did not improve from 0.06792
#
# Epoch 22: val_loss did not improve from 0.06792
#
# Epoch 22: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 22: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0684 - val_loss: 0.0682 - lr: 0.0010
# Epoch 23/40
# 228/235 [============================>.] - ETA: 0s - loss: 0.0680
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 23: val_loss improved from 0.06792 to 0.06761, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 23: val_loss improved from 0.06792 to 0.06761, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 23: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 23: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 7s 29ms/step - loss: 0.0680 - val_loss: 0.0676 - lr: 0.0010
# Epoch 24/40
# 225/235 [===========================>..] - ETA: 0s - loss: 0.0680
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 24: val_loss improved from 0.06761 to 0.06729, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 24: val_loss improved from 0.06761 to 0.06729, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 24: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 24: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 7s 32ms/step - loss: 0.0680 - val_loss: 0.0673 - lr: 0.0010
# Epoch 25/40
# 233/235 [============================>.] - ETA: 0s - loss: 0.0677
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 25: val_loss did not improve from 0.06729
#
# Epoch 25: val_loss did not improve from 0.06729
#
# Epoch 25: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 25: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0677 - val_loss: 0.0677 - lr: 0.0010
# Epoch 26/40
# 231/235 [============================>.] - ETA: 0s - loss: 0.0675
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 26: val_loss improved from 0.06729 to 0.06724, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 26: val_loss improved from 0.06729 to 0.06724, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 26: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 26: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 8s 33ms/step - loss: 0.0675 - val_loss: 0.0672 - lr: 0.0010
# Epoch 27/40
# 234/235 [============================>.] - ETA: 0s - loss: 0.0673
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 27: val_loss did not improve from 0.06724
#
# Epoch 27: val_loss did not improve from 0.06724
#
# Epoch 27: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 27: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 2s 6ms/step - loss: 0.0673 - val_loss: 0.0678 - lr: 0.0010
# Epoch 28/40
# 232/235 [============================>.] - ETA: 0s - loss: 0.0644
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 28: val_loss improved from 0.06724 to 0.06360, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 28: val_loss improved from 0.06724 to 0.06360, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 28: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 28: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 7s 32ms/step - loss: 0.0644 - val_loss: 0.0636 - lr: 0.0010
# Epoch 29/40
# 235/235 [==============================] - ETA: 0s - loss: 0.0637
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 29: val_loss improved from 0.06360 to 0.06340, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 29: val_loss improved from 0.06360 to 0.06340, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 29: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 29: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0637 - val_loss: 0.0634 - lr: 0.0010
# Epoch 30/40
# 228/235 [============================>.] - ETA: 0s - loss: 0.0638
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 30: val_loss did not improve from 0.06340
#
# Epoch 30: val_loss did not improve from 0.06340
#
# Epoch 30: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 30: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# Epoch 30: saving model to model/QAE_model/model_2\KERAS_check_model_epoch30.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0637 - val_loss: 0.0636 - lr: 0.0010
# Epoch 31/40
# 229/235 [============================>.] - ETA: 0s - loss: 0.0640
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 31: val_loss did not improve from 0.06340
#
# Epoch 31: val_loss did not improve from 0.06340
#
# Epoch 31: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 31: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0640 - val_loss: 0.0635 - lr: 0.0010
# Epoch 32/40
# 234/235 [============================>.] - ETA: 0s - loss: 0.0636
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 32: val_loss improved from 0.06340 to 0.06305, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 32: val_loss improved from 0.06340 to 0.06305, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 32: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 32: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 7s 32ms/step - loss: 0.0636 - val_loss: 0.0631 - lr: 0.0010
# Epoch 33/40
# 232/235 [============================>.] - ETA: 0s - loss: 0.0634
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 33: val_loss did not improve from 0.06305
#
# Epoch 33: val_loss did not improve from 0.06305
#
# Epoch 33: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 33: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 2s 6ms/step - loss: 0.0634 - val_loss: 0.0632 - lr: 0.0010
# Epoch 34/40
# 231/235 [============================>.] - ETA: 0s - loss: 0.0630
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 34: val_loss did not improve from 0.06305
#
# Epoch 34: val_loss did not improve from 0.06305
#
# Epoch 34: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 34: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0630 - val_loss: 0.0633 - lr: 0.0010
# Epoch 35/40
# 234/235 [============================>.] - ETA: 0s - loss: 0.0630
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 35: val_loss improved from 0.06305 to 0.06273, saving model to model/QAE_model/model_2\KERAS_check_best_model.model
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# Epoch 35: val_loss improved from 0.06305 to 0.06273, saving model to model/QAE_model/model_2\KERAS_check_best_model_weights.h5
#
# Epoch 35: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 35: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 7s 29ms/step - loss: 0.0630 - val_loss: 0.0627 - lr: 0.0010
# Epoch 36/40
# 230/235 [============================>.] - ETA: 0s - loss: 0.0628
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 36: val_loss did not improve from 0.06273
#
# Epoch 36: val_loss did not improve from 0.06273
#
# Epoch 36: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 36: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0628 - val_loss: 0.0629 - lr: 0.0010
# Epoch 37/40
# 229/235 [============================>.] - ETA: 0s - loss: 0.0627
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 37: val_loss did not improve from 0.06273
#
# Epoch 37: val_loss did not improve from 0.06273
#
# Epoch 37: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 37: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0627 - val_loss: 0.0635 - lr: 0.0010
# Epoch 38/40
# 232/235 [============================>.] - ETA: 0s - loss: 0.0627
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 38: val_loss did not improve from 0.06273
#
# Epoch 38: val_loss did not improve from 0.06273
#
# Epoch 38: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 38: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0627 - val_loss: 0.0631 - lr: 0.0010
# Epoch 39/40
# 229/235 [============================>.] - ETA: 0s - loss: 0.0628
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 39: val_loss did not improve from 0.06273
#
# Epoch 39: val_loss did not improve from 0.06273
#
# Epoch 39: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 39: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 2s 7ms/step - loss: 0.0628 - val_loss: 0.0638 - lr: 0.0010
# Epoch 40/40
# 230/235 [============================>.] - ETA: 0s - loss: 0.0629
# ***callbacks***
# saving losses to model/QAE_model/model_2\losses.log
#
# Epoch 40: val_loss did not improve from 0.06273
#
# Epoch 40: val_loss did not improve from 0.06273
#
# Epoch 40: saving model to model/QAE_model/model_2\KERAS_check_model_last.h5
#
# Epoch 40: saving model to model/QAE_model/model_2\KERAS_check_model_last_weights.h5
#
# Epoch 40: saving model to model/QAE_model/model_2\KERAS_check_model_epoch40.h5
#
# ***callbacks end***
#
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0629 - val_loss: 0.0642 - lr: 0.0010
# 313/313 [==============================] - 1s 2ms/step
# 313/313 [==============================] - 2s 3ms/step
# 313/313 [==============================] - 1s 2ms/step

# %%
network = QAutoencoder(data_zoom, pruned=True)
network.build_encoder()
network.build_decoder()
network.build_autoencoder()
network.fit_data(epochs=40)
network.plot_latent_dimension("Compressed QAE without classifier")
network.plot_reco(model_name=" compressed")
network.plot_score(use_latent_classifier=False,model_name="Compressed QAE without classifier")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 4
#       2 network.build_encoder()
#       3 network.build_decoder()
# ----> 4 network.build_autoencoder()
#       5 network.fit_data(epochs=40)
#       6 network.plot_latent_dimension("Compressed QAE without classifier")
#
# File c:\Users\luisa\OneDrive\Documentos\GitHub\Autoencoder-for-FPGA\class_QAutoencoder.py:240, in QAutoencoder.build_autoencoder(self, use_latent_classifier)
#     234         self.autoencoder.save(
#     235             'model/QAE_model/KERAS_check_pruned_model_w_classifier.h5')
#     237 else:
#     238     # self.autoencoder = Model(
#     239     #     self.input, outputs=self.decoder, name='autoencoder')
# --> 240     self.autoencoder = tf.keras.Model(
#     241         self.input, outputs=self.decoder, name='autoencoder')
#     243     self.autoencoder.compile(loss='mse', optimizer='adam')
#     244     if not self.pruned:
#
# File c:\Users\luisa\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\trackable\base.py:205, in no_automatic_dependency_tracking.<locals>._method_wrapper(self, *args, **kwargs)
#     203 self._self_setattr_tracking = False  # pylint: disable=protected-access
#     204 try:
# --> 205   result = method(self, *args, **kwargs)
#     206 finally:
#     207   self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# File c:\Users\luisa\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\engine\functional.py:166, in Functional.__init__(self, inputs, outputs, name, trainable, **kwargs)
#     157     if not all(
#     158         [
#     159             functional_utils.is_input_keras_tensor(t)
#     160             for t in tf.nest.flatten(inputs)
#     161         ]
#     162     ):
#     163         inputs, outputs = functional_utils.clone_graph_nodes(
#     164             inputs, outputs
#     165         )
# --> 166 self._init_graph_network(inputs, outputs)
#
# File c:\Users\luisa\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\trackable\base.py:205, in no_automatic_dependency_tracking.<locals>._method_wrapper(self, *args, **kwargs)
#     203 self._self_setattr_tracking = False  # pylint: disable=protected-access
#     204 try:
# --> 205   result = method(self, *args, **kwargs)
#     206 finally:
#     207   self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# File c:\Users\luisa\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\engine\functional.py:265, in Functional._init_graph_network(self, inputs, outputs)
#     262     self._input_coordinates.append((layer, node_index, tensor_index))
#     264 # Keep track of the network's nodes and layers.
# --> 265 nodes, nodes_by_depth, layers, _ = _map_graph_network(
#     266     self.inputs, self.outputs
#     267 )
#     268 self._network_nodes = nodes
#     269 self._nodes_by_depth = nodes_by_depth
#
# File c:\Users\luisa\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\engine\functional.py:1144, in _map_graph_network(inputs, outputs)
#    1142 for name in all_names:
#    1143     if all_names.count(name) != 1:
# -> 1144         raise ValueError(
#    1145             f'The name "{name}" is used {all_names.count(name)} '
#    1146             "times in the model. All layer names should be unique."
#    1147         )
#    1148 return network_nodes, nodes_by_depth, layers, layers_by_depth
#
# ValueError: The name "relu3" is used 2 times in the model. All layer names should be unique.

# %% [markdown]
# Repeating the same procedure for the autoencoder with classifier.

# %%
network_with_classifier = QAutoencoder(data_zoom, pruned=False)
network_with_classifier.build_encoder()
#network_with_classifier.build_decoder()
network_with_classifier.build_classifier()
network_with_classifier.build_autoencoder(use_latent_classifier=True)
network_with_classifier.fit_data( batch_size=256,epochs=40, use_latent_classifier=True)
network_with_classifier.plot_latent_dimension("QAutoencoder with classifier")
network_with_classifier.plot_score(use_latent_classifier=True,model_name="QAutoencoder with classifier")

# %% [markdown]
# ### Quantized only classifier

# %%
network_with_classifier = QAutoencoder(data_zoom, pruned=True)
network_with_classifier.build_encoder()
network_with_classifier.build_decoder()
network_with_classifier.build_classifier()
network_with_classifier.build_autoencoder(use_latent_classifier=True)
network_with_classifier.fit_data(epochs=40,use_latent_classifier=True)
network_with_classifier.plot_latent_dimension("Compressed QAE with classifier")
network_with_classifier.plot_score(use_latent_classifier=True,model_name="Compressed QAE with classifier")
